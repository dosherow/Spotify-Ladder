# %% [markdown]
# # Imports & DataFrame Creation

# %%
import pandas as pd
import numpy as np
import os
import pandas_profiling
import seaborn as sns
from matplotlib import pyplot
# %pylab inline
# %matplotlib inline

os.chdir('/Users/drewharrison/Desktop/Playlists/week1condensed')

rap = pd.read_csv('mergedRap324.csv')
rap = rap.reindex(columns=['Artist', 'Track Popularity', 'Track', 'Followers', 'Artist Popularity', 'Release Date',
                           'Date', 'Days Since Release', 'Total Playlists', 'Release To On RapCaviar', 'RapCaviar', 'Days On RapCaviar', 'Release To On Beast Mode', 'Beast Mode',
                           'Days On Beast Mode', 'Release To On Get Turnt', 'Get Turnt', 'Days On Get Turnt', 'Release To On Power Workout', 'Power Workout',
                           'Days On Power Workout', 'Release To On Hot Hits UK', 'Hot Hits UK', 'Days On Hot Hits UK', 'Release To On Most Necessary',
                           'Most Necessary', 'Days On Most Necessary', 'Release To On Top Hits Deutschland', 'Top Hits Deutschland', 'Days On Top Hits Deutschland', 
                           'Release To On Hot Rhythmic', 'Hot Rhythmic', 'Days On Hot Rhythmic', 'Release To On BAE', 'BAE', 'Days On BAE', 'Release To On Love, Sex, & Water', 
                           'Love, Sex, & Water', 'Days On Love, Sex, & Water', 'Release To On Signed XOXO', 'Signed XOXO', 'Days On Signed XOXO', 'Release To On Channel X',
                           'Channel X', 'Days On Channel X', 'Release To On Workout Twerkout', 'Workout Twerkout', 'Days On Workout Twerkout', 'Release To On Hot Hits Australia', 
                           'Hot Hits Australia', 'Days On Hot Hits Australia', 'Release To On Bedroom Jams', 'Bedroom Jams', 'Days On Bedroom Jams', 'Release To On Rap Workout',
                           'Rap Workout', 'Days On Rap Workout', 'Release To On Mellow Bars', 'Mellow Bars', 'Days On Mellow Bars', 'Release To On The Realest Down South', 'The Realest Down South', 
                           'Days On The Realest Down South', 'Release To On Off The Strength', 'Off The Strength', 'Days On Off The Strength', 'Release To On Grime Shutdown', 'Grime Shutdown',
                           'Days On Grime Shutdown', 'Release To On Top Hits NL', 'Top Hits NL', 'Days On Top Hits NL', 'Release To On Hip-Hop Central', 'Hip-Hop Central', 'Days On Hip-Hop Central', 
                           'Release To On Singled Out', 'Singled Out', 'Days On Singled Out', 'Release To On Shisha Lounge', 'Shisha Lounge', 'Days On Shisha Lounge',
                           'Release To On The Newness', 'The Newness', 'Days On The Newness', 'Release To On Locked In', 'Locked In', 'Days On Locked In', 'Release To On Mind Right', 
                           'Mind Right', 'Days On Mind Right', 'Release To On Cali Fire', 'Cali Fire', 'Days On Cali Fire', 'Release To On Rap UK', 'Rap UK', 'Days On Rap UK', 'Release To On Hip-Hop Mixtape',
                           'Hip-Hop Mixtape', 'Days On Hip-Hop Mixtape', 'Release To On Who We Be', 'Who We Be', 'Days On Who We Be', 'Release To On Alternative Hip Hop', 'Alternative Hip Hop', 
                           'Days On Alternative Hip Hop', 'Release To On Swag!', 'Swag!', 'Days On Swag!', 'Release To On Clout Culture', 'Clout Culture', 'Days On Clout Culture', 'Release To On Anti Pop', 
                           'Anti Pop', 'Days On Anti Pop', 'Release To On Spilled Ink', 'Spilled Ink', 'Days On Spilled Ink', 'Release To On R&B Right Now', 'R&B Right Now', 'Days On R&B Right Now', 
                           'Release To On State of Mind', 'State of Mind', 'Days On State of Mind', 'Release To On A1 Hip-Hop', 'A1 Hip-Hop', 'Days On A1 Hip-Hop', 'Release To On Hot Hip Hop', 'Hot Hip Hop',
                           'Days On Hot Hip Hop', 'Release To On Hip-Hop Favourites', 'Hip-Hop Favourites', 'Days On Hip-Hop Favourites', 'Release To On Hip-Hop Yoga', 'Hip-Hop Yoga', 'Days On Hip-Hop Yoga', 
                           'Release To On Beats & Rhymes', 'Beats & Rhymes', 'Days On Beats & Rhymes', 'Release To On Treino Hip-Hop', 'Treino Hip-Hop', 'Days On Treino Hip-Hop', 'Release To On Urban Flavour', 
                           'Urban Flavour', 'Days On Urban Flavour', 'Release To On Afro Bashment', 'Afro Bashment', 'Days On Afro Bashment', 'Release To On New Music Now', 'New Music Now', 'Days On New Music Now', 
                           'Release To On Internet People', 'Internet People', 'Days On Internet People', 'Release To On Hip Hop Mix', 'Hip Hop Mix', 'Days On Hip Hop Mix', 'Release To On Hot Hits New Zealand',
                           'Hot Hits New Zealand', 'Days On Hot Hits New Zealand', 'Release To On 100', '100', 'Days On 100'])
rap = rap.sort_values(by='Total Playlists', ascending=False)
rap.columns = rap.columns.str.replace(' ', '_')
rap['Date'] = pd.to_datetime(rap['Date'])
rap['Release_Date'] = pd.to_datetime(rap['Release_Date'])
rap
# Out:
# Populating the interactive namespace from numpy and matplotlib
#           Artist  Track_Popularity  \
# 803   Lil Yachty                80
# 804   Lil Yachty                80
# 802   Lil Yachty                79
# 801   Lil Yachty                78
# 806   Lil Yachty                81
# ...          ...               ...
# 1466       JYLPO                 0
# 7709  Why Bonnie                 0
# 7710  Why Bonnie                 0
# 4836     Kid Ink                 0
# 2553     Jordana                 0
#
#                                                   Track  Followers  \
# 803   Oprah’s Bank Account (Lil Yachty & DaBaby feat...    6046427
# 804   Oprah’s Bank Account (Lil Yachty & DaBaby feat...    6049418
# 802   Oprah’s Bank Account (Lil Yachty & DaBaby feat...    6043373
# 801   Oprah’s Bank Account (Lil Yachty & DaBaby feat...    6040275
# 806   Oprah’s Bank Account (Lil Yachty & DaBaby feat...    6055473
# ...                                                 ...        ...
# ...

# %%
rapCaviar = rap.loc[rap.RapCaviar==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_RapCaviar', 'Days_On_RapCaviar']]
rapCaviarOn = rapCaviar[rapCaviar.Days_On_RapCaviar.isin([0.0])]
rapCaviarOn['Playlist_Name'] = 'RapCaviar'
rapCaviarOn['Playlist_Followers'] = 12680841
rapCaviarOn['Average_Track_Popularity'] = rapCaviarOn.Track_Popularity.mean()
rapCaviarOn['Average_Artist_Popularity'] = rapCaviarOn.Artist_Popularity.mean()
rapCaviarOn['Average_Total_Playlists'] = rapCaviarOn.Total_Playlists.mean()
rapCaviarOn['Average_Artist_Followers'] = rapCaviarOn.Followers.mean()
rapCaviarOn['Average_Release_To_On'] = rapCaviarOn.Release_To_On_RapCaviar.mean()
rapCaviarOn['Number_Of_Tracks'] = rapCaviarOn.Track.count()
rapCaviarStats = pd.DataFrame(rapCaviarOn.iloc[0:1,9:17])

beastMode = rap.loc[rap.Beast_Mode==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Beast_Mode', 'Days_On_Beast_Mode']]
beastModeOn = beastMode[beastMode.Days_On_Beast_Mode.isin([0.0])]
beastModeOn['Playlist_Name'] = 'Beast_Mode'
beastModeOn['Playlist_Followers'] = 7005235
beastModeOn['Average_Track_Popularity'] = beastModeOn.Track_Popularity.mean()
beastModeOn['Average_Artist_Popularity'] = beastModeOn.Artist_Popularity.mean()
beastModeOn['Average_Total_Playlists'] = beastModeOn.Total_Playlists.mean()
beastModeOn['Average_Artist_Followers'] = beastModeOn.Followers.mean()
beastModeOn['Average_Release_To_On'] = beastModeOn.Release_To_On_Beast_Mode.mean()
beastModeOn['Number_Of_Tracks'] = beastModeOn.Track.count()
beastModeStats = pd.DataFrame(beastModeOn.iloc[0:1,9:17])

getTurnt = rap.loc[rap.Get_Turnt==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Get_Turnt', 'Days_On_Get_Turnt']]
getTurntOn = getTurnt[getTurnt.Days_On_Get_Turnt.isin([0.0])]
getTurntOn['Playlist_Name'] = 'Get_Turnt'
getTurntOn['Playlist_Followers'] = 5864862
getTurntOn['Average_Track_Popularity'] = getTurntOn.Track_Popularity.mean()
getTurntOn['Average_Artist_Popularity'] = getTurntOn.Artist_Popularity.mean()
getTurntOn['Average_Total_Playlists'] = getTurntOn.Total_Playlists.mean()
getTurntOn['Average_Artist_Followers'] = getTurntOn.Followers.mean()
getTurntOn['Average_Release_To_On'] = getTurntOn.Release_To_On_Get_Turnt.mean()
getTurntOn['Number_Of_Tracks'] = getTurntOn.Track.count()
getTurntStats = pd.DataFrame(getTurntOn.iloc[0:1,9:17])

powerWorkout = rap.loc[rap.Power_Workout==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Power_Workout', 'Days_On_Power_Workout']]
powerWorkoutOn = powerWorkout[powerWorkout.Days_On_Power_Workout.isin([0.0])]
powerWorkoutOn['Playlist_Name'] = 'Power_Workout'
powerWorkoutOn['Playlist_Followers'] = 3139541
powerWorkoutOn['Average_Track_Popularity'] = powerWorkoutOn.Track_Popularity.mean()
powerWorkoutOn['Average_Artist_Popularity'] = powerWorkoutOn.Artist_Popularity.mean()
powerWorkoutOn['Average_Total_Playlists'] = powerWorkoutOn.Total_Playlists.mean()
powerWorkoutOn['Average_Artist_Followers'] = powerWorkoutOn.Followers.mean()
powerWorkoutOn['Average_Release_To_On'] = powerWorkoutOn.Release_To_On_Power_Workout.mean()
powerWorkoutOn['Number_Of_Tracks'] = powerWorkoutOn.Track.count()
powerWorkoutStats = pd.DataFrame(powerWorkoutOn.iloc[0:1,9:17])

hotHitsUk = rap.loc[rap.Hot_Hits_UK==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hot_Hits_UK', 'Days_On_Hot_Hits_UK']]
hotHitsUkOn = hotHitsUk[hotHitsUk.Days_On_Hot_Hits_UK.isin([0.0])]
hotHitsUkOn['Playlist_Name'] = 'Hot_Hits_UK'
hotHitsUkOn['Playlist_Followers'] = 2627640
hotHitsUkOn['Average_Track_Popularity'] = hotHitsUkOn.Track_Popularity.mean()
hotHitsUkOn['Average_Artist_Popularity'] = hotHitsUkOn.Artist_Popularity.mean()
hotHitsUkOn['Average_Total_Playlists'] = hotHitsUkOn.Total_Playlists.mean()
hotHitsUkOn['Average_Artist_Followers'] = hotHitsUkOn.Followers.mean()
hotHitsUkOn['Average_Release_To_On'] = hotHitsUkOn.Release_To_On_Hot_Hits_UK.mean()
hotHitsUkOn['Number_Of_Tracks'] = hotHitsUkOn.Track.count()
hotHitsUKStats = pd.DataFrame(hotHitsUkOn.iloc[0:1,9:17])

mostNecessary = rap.loc[rap.Most_Necessary==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Most_Necessary', 'Days_On_Most_Necessary']]
mostNecessaryOn = mostNecessary[mostNecessary.Days_On_Most_Necessary.isin([0.0])]
mostNecessaryOn['Playlist_Name'] = 'Most_Necessary'
mostNecessaryOn['Playlist_Followers'] = 2394067
mostNecessaryOn['Average_Track_Popularity'] = mostNecessaryOn.Track_Popularity.mean()
mostNecessaryOn['Average_Artist_Popularity'] = mostNecessaryOn.Artist_Popularity.mean()
mostNecessaryOn['Average_Total_Playlists'] = mostNecessaryOn.Total_Playlists.mean()
mostNecessaryOn['Average_Artist_Followers'] = mostNecessaryOn.Followers.mean()
mostNecessaryOn['Average_Release_To_On'] = mostNecessaryOn.Release_To_On_Most_Necessary.mean()
mostNecessaryOn['Number_Of_Tracks'] = mostNecessaryOn.Track.count()
mostNecessaryStats = pd.DataFrame(mostNecessaryOn.iloc[0:1,9:17])

hotHitsGermany = rap.loc[rap.Top_Hits_Deutschland==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Top_Hits_Deutschland', 'Days_On_Top_Hits_Deutschland']]
hotHitsGermanyOn = hotHitsGermany[hotHitsGermany.Days_On_Top_Hits_Deutschland.isin([0.0])]
hotHitsGermanyOn['Playlist_Name'] = 'Top_Hits_Germany'
hotHitsGermanyOn['Playlist_Followers'] = 2069701
hotHitsGermanyOn['Average_Track_Popularity'] = hotHitsGermanyOn.Track_Popularity.mean()
hotHitsGermanyOn['Average_Artist_Popularity'] = hotHitsGermanyOn.Artist_Popularity.mean()
hotHitsGermanyOn['Average_Total_Playlists'] = hotHitsGermanyOn.Total_Playlists.mean()
hotHitsGermanyOn['Average_Artist_Followers'] = hotHitsGermanyOn.Followers.mean()
hotHitsGermanyOn['Average_Release_To_On'] = hotHitsGermanyOn.Release_To_On_Top_Hits_Deutschland.mean()
hotHitsGermanyOn['Number_Of_Tracks'] = hotHitsGermanyOn.Track.count()
topHitsGermanyStats = pd.DataFrame(hotHitsGermanyOn.iloc[0:1,9:17])

hotRhythmic = rap.loc[rap.Hot_Rhythmic==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hot_Rhythmic', 'Days_On_Hot_Rhythmic']]
hotRhythmicOn = hotRhythmic[hotRhythmic.Days_On_Hot_Rhythmic.isin([0.0])]
hotRhythmicOn['Playlist_Name'] = 'Hot_Rhythmic'
hotRhythmicOn['Playlist_Followers'] = 1986075
hotRhythmicOn['Average_Track_Popularity'] = hotRhythmicOn.Track_Popularity.mean()
hotRhythmicOn['Average_Artist_Popularity'] = hotRhythmicOn.Artist_Popularity.mean()
hotRhythmicOn['Average_Total_Playlists'] = hotRhythmicOn.Total_Playlists.mean()
hotRhythmicOn['Average_Artist_Followers'] = hotRhythmicOn.Followers.mean()
hotRhythmicOn['Average_Release_To_On'] = hotRhythmicOn.Release_To_On_Hot_Rhythmic.mean()
hotRhythmicOn['Number_Of_Tracks'] = hotRhythmicOn.Track.count()
hotRhythmicStats = pd.DataFrame(hotRhythmicOn.iloc[0:1,9:17])

bae = rap.loc[rap.BAE==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_BAE', 'Days_On_BAE']]
baeOn = bae[bae.Days_On_BAE.isin([0.0])]
baeOn['Playlist_Name'] = 'BAE'
baeOn['Playlist_Followers'] = 1786579
baeOn['Average_Track_Popularity'] = baeOn.Track_Popularity.mean()
baeOn['Average_Artist_Popularity'] = baeOn.Artist_Popularity.mean()
baeOn['Average_Total_Playlists'] = baeOn.Total_Playlists.mean()
baeOn['Average_Artist_Followers'] = baeOn.Followers.mean()
baeOn['Average_Release_To_On'] = baeOn.Release_To_On_BAE.mean()
baeOn['Number_Of_Tracks'] = baeOn.Track.count()
baeStats = pd.DataFrame(baeOn.iloc[0:1,9:17])

lsw = rap.loc[rap['Love,_Sex,_&_Water']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Love,_Sex,_&_Water', 'Days_On_Love,_Sex,_&_Water']]
lswOn = lsw[lsw['Days_On_Love,_Sex,_&_Water'].isin([0.0])]
lswOn['Playlist_Name'] = 'Love_Sex_Water'
lswOn['Playlist_Followers'] = 1786581
lswOn['Average_Track_Popularity'] = lswOn.Track_Popularity.mean()
lswOn['Average_Artist_Popularity'] = lswOn.Artist_Popularity.mean()
lswOn['Average_Total_Playlists'] = lswOn.Total_Playlists.mean()
lswOn['Average_Artist_Followers'] = lswOn.Followers.mean()
lswOn['Average_Release_To_On'] = lswOn['Release_To_On_Love,_Sex,_&_Water'].mean()
lswOn['Number_Of_Tracks'] = lswOn.Track.count()
lswStats = pd.DataFrame(lswOn.iloc[0:1,9:17])

signedXOXO = rap.loc[rap['Signed_XOXO']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Signed_XOXO', 'Days_On_Signed_XOXO']]
signedXOXOOn = signedXOXO[signedXOXO['Days_On_Signed_XOXO'].isin([0.0])]
signedXOXOOn['Playlist_Name'] = 'Signed_XOXO'
signedXOXOOn['Playlist_Followers'] = 1744004
signedXOXOOn['Average_Track_Popularity'] = signedXOXOOn.Track_Popularity.mean()
signedXOXOOn['Average_Artist_Popularity'] = signedXOXOOn.Artist_Popularity.mean()
signedXOXOOn['Average_Total_Playlists'] = signedXOXOOn.Total_Playlists.mean()
signedXOXOOn['Average_Artist_Followers'] = signedXOXOOn.Followers.mean()
signedXOXOOn['Average_Release_To_On'] = signedXOXOOn['Release_To_On_Signed_XOXO'].mean()
signedXOXOOn['Number_Of_Tracks'] = signedXOXOOn.Track.count()
signedXOXOStats = pd.DataFrame(signedXOXOOn.iloc[0:1,9:17])

channelX = rap.loc[rap['Channel_X']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Channel_X', 'Days_On_Channel_X']]
channelXOn = channelX[channelX['Days_On_Channel_X'].isin([0.0])]
channelXOn['Playlist_Name'] = 'Channel_X'
channelXOn['Playlist_Followers'] = 1664495
channelXOn['Average_Track_Popularity'] = channelXOn.Track_Popularity.mean()
channelXOn['Average_Artist_Popularity'] = channelXOn.Artist_Popularity.mean()
channelXOn['Average_Total_Playlists'] = channelXOn.Total_Playlists.mean()
channelXOn['Average_Artist_Followers'] = channelXOn.Followers.mean()
channelXOn['Average_Release_To_On'] = channelXOn['Release_To_On_Channel_X'].mean()
channelXOn['Number_Of_Tracks'] = channelXOn.Track.count()
channelXStats = pd.DataFrame(channelXOn.iloc[0:1,9:17])

workoutTwerkout = rap.loc[rap['Workout_Twerkout']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Workout_Twerkout', 'Days_On_Workout_Twerkout']]
workoutTwerkoutOn = workoutTwerkout[workoutTwerkout['Days_On_Workout_Twerkout'].isin([0.0])]
workoutTwerkoutOn['Playlist_Name'] = 'Workout_Twerkout'
workoutTwerkoutOn['Playlist_Followers'] = 1621255
workoutTwerkoutOn['Average_Track_Popularity'] = workoutTwerkoutOn.Track_Popularity.mean()
workoutTwerkoutOn['Average_Artist_Popularity'] = workoutTwerkoutOn.Artist_Popularity.mean()
workoutTwerkoutOn['Average_Total_Playlists'] = workoutTwerkoutOn.Total_Playlists.mean()
workoutTwerkoutOn['Average_Artist_Followers'] = workoutTwerkoutOn.Followers.mean()
workoutTwerkoutOn['Average_Release_To_On'] = workoutTwerkoutOn['Release_To_On_Workout_Twerkout'].mean()
workoutTwerkoutOn['Number_Of_Tracks'] = workoutTwerkoutOn.Track.count()
workoutTwerkoutStats = pd.DataFrame(workoutTwerkoutOn.iloc[0:1,9:17])

hotHitsAus = rap.loc[rap['Hot_Hits_Australia']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hot_Hits_Australia', 'Days_On_Hot_Hits_Australia']]
hotHitsAusOn = hotHitsAus[hotHitsAus['Days_On_Hot_Hits_Australia'].isin([0.0])]
hotHitsAusOn['Playlist_Name'] = 'Hot_Hits_Aus'
hotHitsAusOn['Playlist_Followers'] = 1206770
hotHitsAusOn['Average_Track_Popularity'] = hotHitsAusOn.Track_Popularity.mean()
hotHitsAusOn['Average_Artist_Popularity'] = hotHitsAusOn.Artist_Popularity.mean()
hotHitsAusOn['Average_Total_Playlists'] = hotHitsAusOn.Total_Playlists.mean()
hotHitsAusOn['Average_Artist_Followers'] = hotHitsAusOn.Followers.mean()
hotHitsAusOn['Average_Release_To_On'] = hotHitsAusOn['Release_To_On_Hot_Hits_Australia'].mean()
hotHitsAusOn['Number_Of_Tracks'] = hotHitsAusOn.Track.count()
hotHitsAusStats = pd.DataFrame(hotHitsAusOn.iloc[0:1,9:17])

bedroomJams = rap.loc[rap['Bedroom_Jams']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Bedroom_Jams', 'Days_On_Bedroom_Jams']]
bedroomJamsOn = bedroomJams[bedroomJams['Days_On_Bedroom_Jams'].isin([0.0])]
bedroomJamsOn['Playlist_Name'] = 'Bedroom_Jams'
bedroomJamsOn['Playlist_Followers'] = 1099262
bedroomJamsOn['Average_Track_Popularity'] = bedroomJamsOn.Track_Popularity.mean()
bedroomJamsOn['Average_Artist_Popularity'] = bedroomJamsOn.Artist_Popularity.mean()
bedroomJamsOn['Average_Total_Playlists'] = bedroomJamsOn.Total_Playlists.mean()
bedroomJamsOn['Average_Artist_Followers'] = bedroomJamsOn.Followers.mean()
bedroomJamsOn['Average_Release_To_On'] = bedroomJamsOn['Release_To_On_Bedroom_Jams'].mean()
bedroomJamsOn['Number_Of_Tracks'] = bedroomJamsOn.Track.count()
bedroomJamsStats = pd.DataFrame(bedroomJamsOn.iloc[0:1,9:17])

rapWorkout = rap.loc[rap['Rap_Workout']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Rap_Workout', 'Days_On_Rap_Workout']]
rapWorkoutOn = rapWorkout[rapWorkout['Days_On_Rap_Workout'].isin([0.0])]
rapWorkoutOn['Playlist_Name'] = 'Rap_Workout'
rapWorkoutOn['Playlist_Followers'] = 1043310
rapWorkoutOn['Average_Track_Popularity'] = rapWorkoutOn.Track_Popularity.mean()
rapWorkoutOn['Average_Artist_Popularity'] = rapWorkoutOn.Artist_Popularity.mean()
rapWorkoutOn['Average_Total_Playlists'] = rapWorkoutOn.Total_Playlists.mean()
rapWorkoutOn['Average_Artist_Followers'] = rapWorkoutOn.Followers.mean()
rapWorkoutOn['Average_Release_To_On'] = rapWorkoutOn['Release_To_On_Rap_Workout'].mean()
rapWorkoutOn['Number_Of_Tracks'] = rapWorkoutOn.Track.count()
rapWorkoutStats = pd.DataFrame(rapWorkoutOn.iloc[0:1,9:17])

mellowBars = rap.loc[rap['Mellow_Bars']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Mellow_Bars', 'Days_On_Mellow_Bars']]
mellowBarsOn = mellowBars[mellowBars['Days_On_Mellow_Bars'].isin([0.0])]
mellowBarsOn['Playlist_Name'] = 'Mellow_Bars'
mellowBarsOn['Playlist_Followers'] = 859103
mellowBarsOn['Average_Track_Popularity'] = mellowBarsOn.Track_Popularity.mean()
mellowBarsOn['Average_Artist_Popularity'] = mellowBarsOn.Artist_Popularity.mean()
mellowBarsOn['Average_Total_Playlists'] = mellowBarsOn.Total_Playlists.mean()
mellowBarsOn['Average_Artist_Followers'] = mellowBarsOn.Followers.mean()
mellowBarsOn['Average_Release_To_On'] = mellowBarsOn['Release_To_On_Mellow_Bars'].mean()
mellowBarsOn['Number_Of_Tracks'] = mellowBarsOn.Track.count()
mellowBarsStats = pd.DataFrame(mellowBarsOn.iloc[0:1,9:17])

realestDownSouth = rap.loc[rap['The_Realest_Down_South']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_The_Realest_Down_South', 'Days_On_The_Realest_Down_South']]
realestDownSouthOn = realestDownSouth[realestDownSouth['Days_On_The_Realest_Down_South'].isin([0.0])]
realestDownSouthOn['Playlist_Name'] = 'Realest_Down_South'
realestDownSouthOn['Playlist_Followers'] = 817759
realestDownSouthOn['Average_Track_Popularity'] = realestDownSouthOn.Track_Popularity.mean()
realestDownSouthOn['Average_Artist_Popularity'] = realestDownSouthOn.Artist_Popularity.mean()
realestDownSouthOn['Average_Total_Playlists'] = realestDownSouthOn.Total_Playlists.mean()
realestDownSouthOn['Average_Artist_Followers'] = realestDownSouthOn.Followers.mean()
realestDownSouthOn['Average_Release_To_On'] = realestDownSouthOn['Release_To_On_The_Realest_Down_South'].mean()
realestDownSouthOn['Number_Of_Tracks'] = realestDownSouthOn.Track.count()
releastDownSouthStats = pd.DataFrame(realestDownSouthOn.iloc[0:1,9:17])

offTheStrength = rap.loc[rap['Off_The_Strength']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Off_The_Strength', 'Days_On_Off_The_Strength']]
offTheStrengthOn = offTheStrength[offTheStrength['Days_On_Off_The_Strength'].isin([0.0])]
offTheStrengthOn['Playlist_Name'] = 'Off_The_Strength'
offTheStrengthOn['Playlist_Followers'] = 778134
offTheStrengthOn['Average_Track_Popularity'] = offTheStrengthOn.Track_Popularity.mean()
offTheStrengthOn['Average_Artist_Popularity'] = offTheStrengthOn.Artist_Popularity.mean()
offTheStrengthOn['Average_Total_Playlists'] = offTheStrengthOn.Total_Playlists.mean()
offTheStrengthOn['Average_Artist_Followers'] = offTheStrengthOn.Followers.mean()
offTheStrengthOn['Average_Release_To_On'] = offTheStrengthOn['Release_To_On_Off_The_Strength'].mean()
offTheStrengthOn['Number_Of_Tracks'] = offTheStrengthOn.Track.count()
offTheStrengthStats = pd.DataFrame(offTheStrengthOn.iloc[0:1,9:17])

grimeShutdown = rap.loc[rap['Grime_Shutdown']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Grime_Shutdown', 'Days_On_Grime_Shutdown']]
grimeShutdownOn = grimeShutdown[grimeShutdown['Days_On_Grime_Shutdown'].isin([0.0])]
grimeShutdownOn['Playlist_Name'] = 'Grime_Shutdown'
grimeShutdownOn['Playlist_Followers'] = 773724
grimeShutdownOn['Average_Track_Popularity'] = grimeShutdownOn.Track_Popularity.mean()
grimeShutdownOn['Average_Artist_Popularity'] = grimeShutdownOn.Artist_Popularity.mean()
grimeShutdownOn['Average_Total_Playlists'] = grimeShutdownOn.Total_Playlists.mean()
grimeShutdownOn['Average_Artist_Followers'] = grimeShutdownOn.Followers.mean()
grimeShutdownOn['Average_Release_To_On'] = grimeShutdownOn['Release_To_On_Grime_Shutdown'].mean()
grimeShutdownOn['Number_Of_Tracks'] = grimeShutdownOn.Track.count()
grimeShutdownStats = pd.DataFrame(grimeShutdownOn.iloc[0:1,9:17])

hitsNL = rap.loc[rap['Top_Hits_NL']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Top_Hits_NL', 'Days_On_Top_Hits_NL']]
hitsNLOn = hitsNL[hitsNL['Days_On_Top_Hits_NL'].isin([0.0])]
hitsNLOn['Playlist_Name'] = 'Top_Hits_NL'
hitsNLOn['Playlist_Followers'] = 755859
hitsNLOn['Average_Track_Popularity'] = hitsNLOn.Track_Popularity.mean()
hitsNLOn['Average_Artist_Popularity'] = hitsNLOn.Artist_Popularity.mean()
hitsNLOn['Average_Total_Playlists'] = hitsNLOn.Total_Playlists.mean()
hitsNLOn['Average_Artist_Followers'] = hitsNLOn.Followers.mean()
hitsNLOn['Average_Release_To_On'] = hitsNLOn['Release_To_On_Top_Hits_NL'].mean()
hitsNLOn['Number_Of_Tracks'] = hitsNLOn.Track.count()
hitsNLStats = pd.DataFrame(hitsNLOn.iloc[0:1,9:17])

hipHopCentral = rap.loc[rap['Hip-Hop_Central']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hip-Hop_Central', 'Days_On_Hip-Hop_Central']]
hipHopCentralOn = hipHopCentral[hipHopCentral['Days_On_Hip-Hop_Central'].isin([0.0])]
hipHopCentralOn['Playlist_Name'] = 'HipHop_Central'
hipHopCentralOn['Playlist_Followers'] = 747753
hipHopCentralOn['Average_Track_Popularity'] = hipHopCentralOn.Track_Popularity.mean()
hipHopCentralOn['Average_Artist_Popularity'] = hipHopCentralOn.Artist_Popularity.mean()
hipHopCentralOn['Average_Total_Playlists'] = hipHopCentralOn.Total_Playlists.mean()
hipHopCentralOn['Average_Artist_Followers'] = hipHopCentralOn.Followers.mean()
hipHopCentralOn['Average_Release_To_On'] = hipHopCentralOn['Release_To_On_Hip-Hop_Central'].mean()
hipHopCentralOn['Number_Of_Tracks'] = hipHopCentralOn.Track.count()
hiphopCentralStats = pd.DataFrame(hipHopCentralOn.iloc[0:1,9:17])

singledOut = rap.loc[rap['Singled_Out']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Singled_Out', 'Days_On_Singled_Out']]
singledOutOn = singledOut[singledOut['Days_On_Singled_Out'].isin([0.0])]
singledOutOn['Playlist_Name'] = 'Singled_Out'
singledOutOn['Playlist_Followers'] = 746328
singledOutOn['Average_Track_Popularity'] = singledOutOn.Track_Popularity.mean()
singledOutOn['Average_Artist_Popularity'] = singledOutOn.Artist_Popularity.mean()
singledOutOn['Average_Total_Playlists'] = singledOutOn.Total_Playlists.mean()
singledOutOn['Average_Artist_Followers'] = singledOutOn.Followers.mean()
singledOutOn['Average_Release_To_On'] = singledOutOn['Release_To_On_Singled_Out'].mean()
singledOutOn['Number_Of_Tracks'] = singledOutOn.Track.count()
singledOutStats = pd.DataFrame(singledOutOn.iloc[0:1,9:17])

shishaLounge = rap.loc[rap['Shisha_Lounge']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Shisha_Lounge', 'Days_On_Shisha_Lounge']]
shishaLoungeOn = shishaLounge[shishaLounge['Days_On_Shisha_Lounge'].isin([0.0])]
shishaLoungeOn['Playlist_Name'] = 'Shisha_Lounge'
shishaLoungeOn['Playlist_Followers'] = 727899
shishaLoungeOn['Average_Track_Popularity'] = shishaLoungeOn.Track_Popularity.mean()
shishaLoungeOn['Average_Artist_Popularity'] = shishaLoungeOn.Artist_Popularity.mean()
shishaLoungeOn['Average_Total_Playlists'] = shishaLoungeOn.Total_Playlists.mean()
shishaLoungeOn['Average_Artist_Followers'] = shishaLoungeOn.Followers.mean()
shishaLoungeOn['Average_Release_To_On'] = shishaLoungeOn['Release_To_On_Shisha_Lounge'].mean()
shishaLoungeOn['Number_Of_Tracks'] = shishaLoungeOn.Track.count()
shishaLoungeStats = pd.DataFrame(shishaLoungeOn.iloc[0:1,9:17])

theNewness = rap.loc[rap['The_Newness']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_The_Newness', 'Days_On_The_Newness']]
theNewnessOn = theNewness[theNewness['Days_On_The_Newness'].isin([0.0])]
theNewnessOn['Playlist_Name'] = 'The_Newness'
theNewnessOn['Playlist_Followers'] = 720207
theNewnessOn['Average_Track_Popularity'] = theNewnessOn.Track_Popularity.mean()
theNewnessOn['Average_Artist_Popularity'] = theNewnessOn.Artist_Popularity.mean()
theNewnessOn['Average_Total_Playlists'] = theNewnessOn.Total_Playlists.mean()
theNewnessOn['Average_Artist_Followers'] = theNewnessOn.Followers.mean()
theNewnessOn['Average_Release_To_On'] = theNewnessOn['Release_To_On_The_Newness'].mean()
theNewnessOn['Number_Of_Tracks'] = theNewnessOn.Track.count()
theNewnessStats = pd.DataFrame(theNewnessOn.iloc[0:1,9:17])

lockedIn = rap.loc[rap['Locked_In']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Locked_In', 'Days_On_Locked_In']]
lockedInOn = lockedIn[lockedIn['Days_On_Locked_In'].isin([0.0])]
lockedInOn['Playlist_Name'] = 'Locked_In'
lockedInOn['Playlist_Followers'] = 718439
lockedInOn['Average_Track_Popularity'] = lockedInOn.Track_Popularity.mean()
lockedInOn['Average_Artist_Popularity'] = lockedInOn.Artist_Popularity.mean()
lockedInOn['Average_Total_Playlists'] = lockedInOn.Total_Playlists.mean()
lockedInOn['Average_Artist_Followers'] = lockedInOn.Followers.mean()
lockedInOn['Average_Release_To_On'] = lockedInOn['Release_To_On_Locked_In'].mean()
lockedInOn['Number_Of_Tracks'] = lockedInOn.Track.count()
lockedInStats = pd.DataFrame(lockedInOn.iloc[0:1,9:17])

mindRight = rap.loc[rap['Mind_Right']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Mind_Right', 'Days_On_Mind_Right']]
mindRightOn = mindRight[mindRight['Days_On_Mind_Right'].isin([0.0])]
mindRightOn['Playlist_Name'] = 'Mind_Right'
mindRightOn['Playlist_Followers'] = 644934
mindRightOn['Average_Track_Popularity'] = mindRightOn.Track_Popularity.mean()
mindRightOn['Average_Artist_Popularity'] = mindRightOn.Artist_Popularity.mean()
mindRightOn['Average_Total_Playlists'] = mindRightOn.Total_Playlists.mean()
mindRightOn['Average_Artist_Followers'] = mindRightOn.Followers.mean()
mindRightOn['Average_Release_To_On'] = mindRightOn['Release_To_On_Mind_Right'].mean()
mindRightOn['Number_Of_Tracks'] = mindRightOn.Track.count()
mindRightStats = pd.DataFrame(mindRightOn.iloc[0:1,9:17])

caliFire = rap.loc[rap['Cali_Fire']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Cali_Fire', 'Days_On_Cali_Fire']]
caliFireOn = caliFire[caliFire['Days_On_Cali_Fire'].isin([0.0])]
caliFireOn['Playlist_Name'] = 'Cali_Fire'
caliFireOn['Playlist_Followers'] = 623094
caliFireOn['Average_Track_Popularity'] = caliFireOn.Track_Popularity.mean()
caliFireOn['Average_Artist_Popularity'] = caliFireOn.Artist_Popularity.mean()
caliFireOn['Average_Total_Playlists'] = caliFireOn.Total_Playlists.mean()
caliFireOn['Average_Artist_Followers'] = caliFireOn.Followers.mean()
caliFireOn['Average_Release_To_On'] = caliFireOn['Release_To_On_Cali_Fire'].mean()
caliFireOn['Number_Of_Tracks'] = caliFireOn.Track.count()
caliFireStats = pd.DataFrame(caliFireOn.iloc[0:1,9:17])

rapUk = rap.loc[rap['Rap_UK']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Rap_UK', 'Days_On_Rap_UK']]
rapUkOn = rapUk[rapUk['Days_On_Rap_UK'].isin([0.0])]
rapUkOn['Playlist_Name'] = 'Rap_UK'
rapUkOn['Playlist_Followers'] = 621037
rapUkOn['Average_Track_Popularity'] = rapUkOn.Track_Popularity.mean()
rapUkOn['Average_Artist_Popularity'] = rapUkOn.Artist_Popularity.mean()
rapUkOn['Average_Total_Playlists'] = rapUkOn.Total_Playlists.mean()
rapUkOn['Average_Artist_Followers'] = rapUkOn.Followers.mean()
rapUkOn['Average_Release_To_On'] = rapUkOn['Release_To_On_Rap_UK'].mean()
rapUkOn['Number_Of_Tracks'] = rapUkOn.Track.count()
rapUkStats = pd.DataFrame(rapUkOn.iloc[0:1,9:17])

hipHopMixtape = rap.loc[rap['Hip-Hop_Mixtape']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hip-Hop_Mixtape', 'Days_On_Hip-Hop_Mixtape']]
hipHopMixtapeOn = hipHopMixtape[hipHopMixtape['Days_On_Hip-Hop_Mixtape'].isin([0.0])]
hipHopMixtapeOn['Playlist_Name'] = 'Hiphop_Mixtape'
hipHopMixtapeOn['Playlist_Followers'] = 615400
hipHopMixtapeOn['Average_Track_Popularity'] = hipHopMixtapeOn.Track_Popularity.mean()
hipHopMixtapeOn['Average_Artist_Popularity'] = hipHopMixtapeOn.Artist_Popularity.mean()
hipHopMixtapeOn['Average_Total_Playlists'] = hipHopMixtapeOn.Total_Playlists.mean()
hipHopMixtapeOn['Average_Artist_Followers'] = hipHopMixtapeOn.Followers.mean()
hipHopMixtapeOn['Average_Release_To_On'] = hipHopMixtapeOn['Release_To_On_Hip-Hop_Mixtape'].mean()
hipHopMixtapeOn['Number_Of_Tracks'] = hipHopMixtapeOn.Track.count()
hiphopMixtapeStats = pd.DataFrame(hipHopMixtapeOn.iloc[0:1,9:17])

whoWeBe = rap.loc[rap['Who_We_Be']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Who_We_Be', 'Days_On_Who_We_Be']]
whoWeBeOn = whoWeBe[whoWeBe['Days_On_Who_We_Be'].isin([0.0])]
whoWeBeOn['Playlist_Name'] = 'Who_We_Be'
whoWeBeOn['Playlist_Followers'] = 593416
whoWeBeOn['Average_Track_Popularity'] = whoWeBeOn.Track_Popularity.mean()
whoWeBeOn['Average_Artist_Popularity'] = whoWeBeOn.Artist_Popularity.mean()
whoWeBeOn['Average_Total_Playlists'] = whoWeBeOn.Total_Playlists.mean()
whoWeBeOn['Average_Artist_Followers'] = whoWeBeOn.Followers.mean()
whoWeBeOn['Average_Release_To_On'] = whoWeBeOn['Release_To_On_Who_We_Be'].mean()
whoWeBeOn['Number_Of_Tracks'] = whoWeBeOn.Track.count()
whoWeBeStats = pd.DataFrame(whoWeBeOn.iloc[0:1,9:17])

altHipHop = rap.loc[rap['Alternative_Hip_Hop']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Alternative_Hip_Hop', 'Days_On_Alternative_Hip_Hop']]
altHipHopOn = altHipHop[altHipHop['Days_On_Alternative_Hip_Hop'].isin([0.0])]
altHipHopOn['Playlist_Name'] = 'Alternative_HipHop'
altHipHopOn['Playlist_Followers'] = 576313
altHipHopOn['Average_Track_Popularity'] = altHipHopOn.Track_Popularity.mean()
altHipHopOn['Average_Artist_Popularity'] = altHipHopOn.Artist_Popularity.mean()
altHipHopOn['Average_Total_Playlists'] = altHipHopOn.Total_Playlists.mean()
altHipHopOn['Average_Artist_Followers'] = altHipHopOn.Followers.mean()
altHipHopOn['Average_Release_To_On'] = altHipHopOn['Release_To_On_Alternative_Hip_Hop'].mean()
altHipHopOn['Number_Of_Tracks'] = altHipHopOn.Track.count()
altHipHopStats = pd.DataFrame(altHipHopOn.iloc[0:1,9:17])

swag = rap.loc[rap['Swag!']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Swag!', 'Days_On_Swag!']]
swagOn = swag[swag['Days_On_Swag!'].isin([0.0])]
swagOn['Playlist_Name'] = 'Swag'
swagOn['Playlist_Followers'] = 573090
swagOn['Average_Track_Popularity'] = swagOn.Track_Popularity.mean()
swagOn['Average_Artist_Popularity'] = swagOn.Artist_Popularity.mean()
swagOn['Average_Total_Playlists'] = swagOn.Total_Playlists.mean()
swagOn['Average_Artist_Followers'] = swagOn.Followers.mean()
swagOn['Average_Release_To_On'] = swagOn['Release_To_On_Swag!'].mean()
swagOn['Number_Of_Tracks'] = swagOn.Track.count()
swagStats = pd.DataFrame(swagOn.iloc[0:1,9:17])

cloutCulture = rap.loc[rap['Clout_Culture']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Clout_Culture', 'Days_On_Clout_Culture']]
cloutCultureOn = cloutCulture[cloutCulture['Days_On_Clout_Culture'].isin([0.0])]
cloutCultureOn['Playlist_Name'] = 'Clout_Culture'
cloutCultureOn['Playlist_Followers'] = 564846
cloutCultureOn['Average_Track_Popularity'] = cloutCultureOn.Track_Popularity.mean()
cloutCultureOn['Average_Artist_Popularity'] = cloutCultureOn.Artist_Popularity.mean()
cloutCultureOn['Average_Total_Playlists'] = cloutCultureOn.Total_Playlists.mean()
cloutCultureOn['Average_Artist_Followers'] = cloutCultureOn.Followers.mean()
cloutCultureOn['Average_Release_To_On'] = cloutCultureOn['Release_To_On_Clout_Culture'].mean()
cloutCultureOn['Number_Of_Tracks'] = cloutCultureOn.Track.count()
cloutCultureStats = pd.DataFrame(cloutCultureOn.iloc[0:1,9:17])

antiPop = rap.loc[rap['Anti_Pop']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Anti_Pop', 'Days_On_Anti_Pop']]
antiPopOn = antiPop[antiPop['Days_On_Anti_Pop'].isin([0.0])]
antiPopOn['Playlist_Name'] = 'Anti_Pop'
antiPopOn['Playlist_Followers'] = 534584
antiPopOn['Average_Track_Popularity'] = antiPopOn.Track_Popularity.mean()
antiPopOn['Average_Artist_Popularity'] = antiPopOn.Artist_Popularity.mean()
antiPopOn['Average_Total_Playlists'] = antiPopOn.Total_Playlists.mean()
antiPopOn['Average_Artist_Followers'] = antiPopOn.Followers.mean()
antiPopOn['Average_Release_To_On'] = antiPopOn['Release_To_On_Anti_Pop'].mean()
antiPopOn['Number_Of_Tracks'] = antiPopOn.Track.count()
antiPopStats = pd.DataFrame(antiPopOn.iloc[0:1,9:17])

spilledInk = rap.loc[rap['Spilled_Ink']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Spilled_Ink', 'Days_On_Spilled_Ink']]
spilledInkOn = spilledInk[spilledInk['Days_On_Spilled_Ink'].isin([0.0])]
spilledInkOn['Playlist_Name'] = 'Spilled_Ink'
spilledInkOn['Playlist_Followers'] = 402013
spilledInkOn['Average_Track_Popularity'] = spilledInkOn.Track_Popularity.mean()
spilledInkOn['Average_Artist_Popularity'] = spilledInkOn.Artist_Popularity.mean()
spilledInkOn['Average_Total_Playlists'] = spilledInkOn.Total_Playlists.mean()
spilledInkOn['Average_Artist_Followers'] = spilledInkOn.Followers.mean()
spilledInkOn['Average_Release_To_On'] = spilledInkOn['Release_To_On_Spilled_Ink'].mean()
spilledInkOn['Number_Of_Tracks'] = spilledInkOn.Track.count()
spilledInkStats = pd.DataFrame(spilledInkOn.iloc[0:1,9:17])

rbrn = rap.loc[rap['R&B_Right_Now']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_R&B_Right_Now', 'Days_On_R&B_Right_Now']]
rbrnOn = rbrn[rbrn['Days_On_R&B_Right_Now'].isin([0.0])]
rbrnOn['Playlist_Name'] = 'RnB_Now'
rbrnOn['Playlist_Followers'] = 321715
rbrnOn['Average_Track_Popularity'] = rbrnOn.Track_Popularity.mean()
rbrnOn['Average_Artist_Popularity'] = rbrnOn.Artist_Popularity.mean()
rbrnOn['Average_Total_Playlists'] = rbrnOn.Total_Playlists.mean()
rbrnOn['Average_Artist_Followers'] = rbrnOn.Followers.mean()
rbrnOn['Average_Release_To_On'] = rbrnOn['Release_To_On_R&B_Right_Now'].mean()
rbrnOn['Number_Of_Tracks'] = rbrnOn.Track.count()
rbrnStats = pd.DataFrame(rbrnOn.iloc[0:1,9:17])

stateOfMind = rap.loc[rap['State_of_Mind']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_State_of_Mind', 'Days_On_State_of_Mind']]
stateOfMindOn = stateOfMind[stateOfMind['Days_On_State_of_Mind'].isin([0.0])]
stateOfMindOn['Playlist_Name'] = 'State_Of_Mind'
stateOfMindOn['Playlist_Followers'] = 316833
stateOfMindOn['Average_Track_Popularity'] = stateOfMindOn.Track_Popularity.mean()
stateOfMindOn['Average_Artist_Popularity'] = stateOfMindOn.Artist_Popularity.mean()
stateOfMindOn['Average_Total_Playlists'] = stateOfMindOn.Total_Playlists.mean()
stateOfMindOn['Average_Artist_Followers'] = stateOfMindOn.Followers.mean()
stateOfMindOn['Average_Release_To_On'] = stateOfMindOn['Release_To_On_State_of_Mind'].mean()
stateOfMindOn['Number_Of_Tracks'] = stateOfMindOn.Track.count()
stateOfMindStats = pd.DataFrame(stateOfMindOn.iloc[0:1,9:17])

a1HH = rap.loc[rap['A1_Hip-Hop']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_A1_Hip-Hop', 'Days_On_A1_Hip-Hop']]
a1HHOn = a1HH[a1HH['Days_On_A1_Hip-Hop'].isin([0.0])]
a1HHOn['Playlist_Name'] = 'A1_HipHop'
a1HHOn['Playlist_Followers'] = 300787
a1HHOn['Average_Track_Popularity'] = a1HHOn.Track_Popularity.mean()
a1HHOn['Average_Artist_Popularity'] = a1HHOn.Artist_Popularity.mean()
a1HHOn['Average_Total_Playlists'] = a1HHOn.Total_Playlists.mean()
a1HHOn['Average_Artist_Followers'] = a1HHOn.Followers.mean()
a1HHOn['Average_Release_To_On'] = a1HHOn['Release_To_On_A1_Hip-Hop'].mean()
a1HHOn['Number_Of_Tracks'] = a1HHOn.Track.count()
a1HipHopStats = pd.DataFrame(a1HHOn.iloc[0:1,9:17])

hotHipHop = rap.loc[rap['Hot_Hip_Hop']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hot_Hip_Hop', 'Days_On_Hot_Hip_Hop']]
hotHipHopOn = hotHipHop[hotHipHop['Days_On_Hot_Hip_Hop'].isin([0.0])]
hotHipHopOn['Playlist_Name'] = 'Hot_HipHop'
hotHipHopOn['Playlist_Followers'] = 296220
hotHipHopOn['Average_Track_Popularity'] = hotHipHopOn.Track_Popularity.mean()
hotHipHopOn['Average_Artist_Popularity'] = hotHipHopOn.Artist_Popularity.mean()
hotHipHopOn['Average_Total_Playlists'] = hotHipHopOn.Total_Playlists.mean()
hotHipHopOn['Average_Artist_Followers'] = hotHipHopOn.Followers.mean()
hotHipHopOn['Average_Release_To_On'] = hotHipHopOn['Release_To_On_Hot_Hip_Hop'].mean()
hotHipHopOn['Number_Of_Tracks'] = hotHipHopOn.Track.count()
hotHipHopStats = pd.DataFrame(hotHipHopOn.iloc[0:1,9:17])

hipHopFav = rap.loc[rap['Hip-Hop_Favourites']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hip-Hop_Favourites', 'Days_On_Hip-Hop_Favourites']]
hipHopFavOn = hipHopFav[hipHopFav['Days_On_Hip-Hop_Favourites'].isin([0.0])]
hipHopFavOn['Playlist_Name'] = 'HipHop_Favorites'
hipHopFavOn['Playlist_Followers'] = 282568
hipHopFavOn['Average_Track_Popularity'] = hipHopFavOn.Track_Popularity.mean()
hipHopFavOn['Average_Artist_Popularity'] = hipHopFavOn.Artist_Popularity.mean()
hipHopFavOn['Average_Total_Playlists'] = hipHopFavOn.Total_Playlists.mean()
hipHopFavOn['Average_Artist_Followers'] = hipHopFavOn.Followers.mean()
hipHopFavOn['Average_Release_To_On'] = hipHopFavOn['Release_To_On_Hip-Hop_Favourites'].mean()
hipHopFavOn['Number_Of_Tracks'] = hipHopFavOn.Track.count()
hipHopFavStats = pd.DataFrame(hipHopFavOn.iloc[0:1,9:17])

hipHopYoga = rap.loc[rap['Hip-Hop_Yoga']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hip-Hop_Yoga', 'Days_On_Hip-Hop_Yoga']]
hipHopYogaOn = hipHopYoga[hipHopYoga['Days_On_Hip-Hop_Yoga'].isin([0.0])]
hipHopYogaOn['Playlist_Name'] = 'HipHop_Yoga'
hipHopYogaOn['Playlist_Followers'] = 272221
hipHopYogaOn['Average_Track_Popularity'] = hipHopYogaOn.Track_Popularity.mean()
hipHopYogaOn['Average_Artist_Popularity'] = hipHopYogaOn.Artist_Popularity.mean()
hipHopYogaOn['Average_Total_Playlists'] = hipHopYogaOn.Total_Playlists.mean()
hipHopYogaOn['Average_Artist_Followers'] = hipHopYogaOn.Followers.mean()
hipHopYogaOn['Average_Release_To_On'] = hipHopYogaOn['Release_To_On_Hip-Hop_Yoga'].mean()
hipHopYogaOn['Number_Of_Tracks'] = hipHopYogaOn.Track.count()
hipHopYogaStats = pd.DataFrame(hipHopYogaOn.iloc[0:1,9:17])

beatsAndRhymes = rap.loc[rap['Beats_&_Rhymes']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Beats_&_Rhymes', 'Days_On_Beats_&_Rhymes']]
beatsAndRhymesOn = beatsAndRhymes[beatsAndRhymes['Days_On_Beats_&_Rhymes'].isin([0.0])]
beatsAndRhymesOn['Playlist_Name'] = 'Beats_And_Rhymes'
beatsAndRhymesOn['Playlist_Followers'] = 264599
beatsAndRhymesOn['Average_Track_Popularity'] = beatsAndRhymesOn.Track_Popularity.mean()
beatsAndRhymesOn['Average_Artist_Popularity'] = beatsAndRhymesOn.Artist_Popularity.mean()
beatsAndRhymesOn['Average_Total_Playlists'] = beatsAndRhymesOn.Total_Playlists.mean()
beatsAndRhymesOn['Average_Artist_Followers'] = beatsAndRhymesOn.Followers.mean()
beatsAndRhymesOn['Average_Release_To_On'] = beatsAndRhymesOn['Release_To_On_Beats_&_Rhymes'].mean()
beatsAndRhymesOn['Number_Of_Tracks'] = beatsAndRhymesOn.Track.count()
beatsAndRhymesStats = pd.DataFrame(beatsAndRhymesOn.iloc[0:1,9:17])

treino = rap.loc[rap['Treino_Hip-Hop']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Treino_Hip-Hop', 'Days_On_Treino_Hip-Hop']]
treinoOn = treino[treino['Days_On_Treino_Hip-Hop'].isin([0.0])]
treinoOn['Playlist_Name'] = 'Treino_Hip_Hop'
treinoOn['Playlist_Followers'] = 250630
treinoOn['Average_Track_Popularity'] = treinoOn.Track_Popularity.mean()
treinoOn['Average_Artist_Popularity'] = treinoOn.Artist_Popularity.mean()
treinoOn['Average_Total_Playlists'] = treinoOn.Total_Playlists.mean()
treinoOn['Average_Artist_Followers'] = treinoOn.Followers.mean()
treinoOn['Average_Release_To_On'] = treinoOn['Release_To_On_Treino_Hip-Hop'].mean()
treinoOn['Number_Of_Tracks'] = treinoOn.Track.count()
treinoStats = pd.DataFrame(treinoOn.iloc[0:1,9:17])

urbanFlavor = rap.loc[rap['Urban_Flavour']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Urban_Flavour', 'Days_On_Urban_Flavour']]
urbanFlavorOn = urbanFlavor[urbanFlavor['Days_On_Urban_Flavour'].isin([0.0])]
urbanFlavorOn['Playlist_Name'] = 'Urban_Flavor'
urbanFlavorOn['Playlist_Followers'] = 229983
urbanFlavorOn['Average_Track_Popularity'] = urbanFlavorOn.Track_Popularity.mean()
urbanFlavorOn['Average_Artist_Popularity'] = urbanFlavorOn.Artist_Popularity.mean()
urbanFlavorOn['Average_Total_Playlists'] = urbanFlavorOn.Total_Playlists.mean()
urbanFlavorOn['Average_Artist_Followers'] = urbanFlavorOn.Followers.mean()
urbanFlavorOn['Average_Release_To_On'] = urbanFlavorOn['Release_To_On_Urban_Flavour'].mean()
urbanFlavorOn['Number_Of_Tracks'] = urbanFlavorOn.Track.count()
urbanFlavorStats = pd.DataFrame(urbanFlavorOn.iloc[0:1,9:17])

afroBashment = rap.loc[rap['Afro_Bashment']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Afro_Bashment', 'Days_On_Afro_Bashment']]
afroBashmentOn = afroBashment[afroBashment['Days_On_Afro_Bashment'].isin([0.0])]
afroBashmentOn['Playlist_Name'] = 'Afro_Bashment'
afroBashmentOn['Playlist_Followers'] = 227422
afroBashmentOn['Average_Track_Popularity'] = afroBashmentOn.Track_Popularity.mean()
afroBashmentOn['Average_Artist_Popularity'] = afroBashmentOn.Artist_Popularity.mean()
afroBashmentOn['Average_Total_Playlists'] = afroBashmentOn.Total_Playlists.mean()
afroBashmentOn['Average_Artist_Followers'] = afroBashmentOn.Followers.mean()
afroBashmentOn['Average_Release_To_On'] = afroBashmentOn['Release_To_On_Afro_Bashment'].mean()
afroBashmentOn['Number_Of_Tracks'] = afroBashmentOn.Track.count()
afroBashmentStats = pd.DataFrame(afroBashmentOn.iloc[0:1,9:17])

newMusicNow = rap.loc[rap['New_Music_Now']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_New_Music_Now', 'Days_On_New_Music_Now']]
newMusicNowOn = newMusicNow[newMusicNow['Days_On_New_Music_Now'].isin([0.0])]
newMusicNowOn['Playlist_Name'] = 'New_Music_Now'
newMusicNowOn['Playlist_Followers'] = 210490
newMusicNowOn['Average_Track_Popularity'] = newMusicNowOn.Track_Popularity.mean()
newMusicNowOn['Average_Artist_Popularity'] = newMusicNowOn.Artist_Popularity.mean()
newMusicNowOn['Average_Total_Playlists'] = newMusicNowOn.Total_Playlists.mean()
newMusicNowOn['Average_Artist_Followers'] = newMusicNowOn.Followers.mean()
newMusicNowOn['Average_Release_To_On'] = newMusicNowOn['Release_To_On_New_Music_Now'].mean()
newMusicNowOn['Number_Of_Tracks'] = newMusicNowOn.Track.count()
newMusicNowStats = pd.DataFrame(newMusicNowOn.iloc[0:1,9:17])

hipHopMix = rap.loc[rap['Hip_Hop_Mix']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hip_Hop_Mix', 'Days_On_Hip_Hop_Mix']]
hipHopMixOn = hipHopMix[hipHopMix['Days_On_Hip_Hop_Mix'].isin([0.0])]
hipHopMixOn['Playlist_Name'] = 'HipHop_Mix'
hipHopMixOn['Playlist_Followers'] = 163261
hipHopMixOn['Average_Track_Popularity'] = hipHopMixOn.Track_Popularity.mean()
hipHopMixOn['Average_Artist_Popularity'] = hipHopMixOn.Artist_Popularity.mean()
hipHopMixOn['Average_Total_Playlists'] = hipHopMixOn.Total_Playlists.mean()
hipHopMixOn['Average_Artist_Followers'] = hipHopMixOn.Followers.mean()
hipHopMixOn['Average_Release_To_On'] = hipHopMixOn['Release_To_On_Hip_Hop_Mix'].mean()
hipHopMixOn['Number_Of_Tracks'] = hipHopMixOn.Track.count()
hipHopMixStats = pd.DataFrame(hipHopMixOn.iloc[0:1,9:17])

hitsNZ = rap.loc[rap['Hot_Hits_New_Zealand']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Hot_Hits_New_Zealand', 'Days_On_Hot_Hits_New_Zealand']]
hitsNZOn = hitsNZ[hitsNZ['Days_On_Hot_Hits_New_Zealand'].isin([0.0])]
hitsNZOn['Playlist_Name'] = 'Top_Hits_NZ'
hitsNZOn['Playlist_Followers'] = 153717
hitsNZOn['Average_Track_Popularity'] = hitsNZOn.Track_Popularity.mean()
hitsNZOn['Average_Artist_Popularity'] = hitsNZOn.Artist_Popularity.mean()
hitsNZOn['Average_Total_Playlists'] = hitsNZOn.Total_Playlists.mean()
hitsNZOn['Average_Artist_Followers'] = hitsNZOn.Followers.mean()
hitsNZOn['Average_Release_To_On'] = hitsNZOn['Release_To_On_Hot_Hits_New_Zealand'].mean()
hitsNZOn['Number_Of_Tracks'] = hitsNZOn.Track.count()
hitsNZStats = pd.DataFrame(hitsNZOn.iloc[0:1,9:17])

internetPeople = rap.loc[rap['Internet_People']==1,['Artist', 'Track', 'Track_Popularity', 'Artist_Popularity', 'Followers', 'Total_Playlists', 'Days_Since_Release', 'Release_To_On_Internet_People', 'Days_On_Internet_People']]
internetPeopleOn = internetPeople[internetPeople['Days_On_Internet_People'].isin([0.0])]
internetPeopleOn['Playlist_Name'] = 'Internet_People'
internetPeopleOn['Playlist_Followers'] = 191167
internetPeopleOn['Average_Track_Popularity'] = internetPeopleOn.Track_Popularity.mean()
internetPeopleOn['Average_Artist_Popularity'] = internetPeopleOn.Artist_Popularity.mean()
internetPeopleOn['Average_Total_Playlists'] = internetPeopleOn.Total_Playlists.mean()
internetPeopleOn['Average_Artist_Followers'] = internetPeopleOn.Followers.mean()
internetPeopleOn['Average_Release_To_On'] = internetPeopleOn['Release_To_On_Internet_People'].mean()
internetPeopleOn['Number_Of_Tracks'] = internetPeopleOn.Track.count()
internetPeopleStats = pd.DataFrame(internetPeopleOn.iloc[0:1,9:17])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# ...

# %% [markdown]
# # Individual Playlist Exploration

# %%
plt.figure(figsize=(15, 7))

newMusicNowOn_chart = sns.scatterplot(x='Days_Since_Release',
                        y='Artist_Popularity',
                        hue='Total_Playlists',
                        data=newMusicNowOn).set_title('New Music Now Tracks: Release to On vs. Artist Popularity')

plt.show()

# %%
plt.figure(figsize=(15, 7))

internetPeopleOn_chart = sns.boxplot(x='Days_Since_Release',
                        y='Artist_Popularity',
                        hue='Total_Playlists',
                        data=internetPeopleOn)

plt.show()

# %%
plt.figure(figsize=(15, 7))

afroBashmentOn_chart = sns.catplot(x='Days_Since_Release',
                        y='Artist_Popularity',
                        kind='violin',
                        inner=None,
                        data=afroBashmentOn)
sns.swarmplot(x='Days_Since_Release',
              y='Artist_Popularity',
              color='k',
              size=3,
              data=afroBashmentOn,
              ax=afroBashmentOn_chart.ax)

plt.show()

# %% [markdown]
# # Exploratory Aggregation

# %%
rapStatsAgg = pd.concat([rapCaviarStats, beastModeStats, getTurntStats, powerWorkoutStats, hotHitsUKStats,
                        mostNecessaryStats, topHitsGermanyStats, hotRhythmicStats, baeStats, lswStats,
                        signedXOXOStats, channelXStats, workoutTwerkoutStats, hotHitsAusStats, bedroomJamsStats,
                        rapWorkoutStats, mellowBarsStats, releastDownSouthStats, offTheStrengthStats, grimeShutdownStats,
                        hitsNLStats, hiphopCentralStats, singledOutStats, shishaLoungeStats, theNewnessStats,
                        lockedInStats, mindRightStats, caliFireStats, rapUkStats, hiphopMixtapeStats, whoWeBeStats,
                        altHipHopStats, swagStats, cloutCultureStats, antiPopStats, spilledInkStats, rbrnStats,
                        stateOfMindStats, a1HipHopStats, hotHipHopStats, hipHopFavStats, hipHopYogaStats, beatsAndRhymesStats,
                        treinoStats, urbanFlavorStats, afroBashmentStats, newMusicNowStats, hipHopMixStats, hitsNZStats,
                        internetPeopleStats], ignore_index=True)
rapStatsAgg.reset_index(drop=True)
format_dict = {'Playlist_Followers':'{:,}', 'Average_Artist_Followers':'{:,.0f}', 'Average_Track_Popularity':'{:.2f}', 'Average_Artist_Popularity':'{:.2f}',
              'Average_Total_Playlists':'{:.2f}', 'Average_Release_To_On':'{:.2f}'}
rapStatsAgg.sort_values('Average_Release_To_On', ascending=False).style.format(format_dict).hide_index().background_gradient(subset='Average_Release_To_On', cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_f5c835ce_704a_11ea_a9bb_3af9d3abd3acrow0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f5c835ce_704a_11ea_a9bb_3af9d3abd3acrow1_col6 {
#             background-color:  #083674;
#             color:  #f1f1f1;
#         }    #T_f5c835ce_704a_11ea_a9bb_3af9d3abd3acrow2_col6 {
#             background-color:  #084184;
#             color:  #f1f1f1;
#         }    #T_f5c835ce_704a_11ea_a9bb_3af9d3abd3acrow3_col6 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_f5c835ce_704a_11ea_a9bb_3af9d3abd3acrow4_col6 {
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }    #T_f5c835ce_704a_11ea_a9bb_3af9d3abd3acrow5_col6 {
#             background-color:  #3e8ec4;
#             color:  #000000;
#         }    #T_f5c835ce_704a_11ea_a9bb_3af9d3abd3acrow6_col6 {
#             background-color:  #519ccc;
#             color:  #000000;
# ...

# %%
rapStatsAgg.sort_values('Average_Artist_Popularity', ascending=False).style.format(format_dict).hide_index().background_gradient(subset='Average_Artist_Popularity', cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_0b9c650a_704b_11ea_a9bb_3af9d3abd3acrow0_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_0b9c650a_704b_11ea_a9bb_3af9d3abd3acrow1_col3 {
#             background-color:  #006328;
#             color:  #f1f1f1;
#         }    #T_0b9c650a_704b_11ea_a9bb_3af9d3abd3acrow2_col3 {
#             background-color:  #006428;
#             color:  #f1f1f1;
#         }    #T_0b9c650a_704b_11ea_a9bb_3af9d3abd3acrow3_col3 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_0b9c650a_704b_11ea_a9bb_3af9d3abd3acrow4_col3 {
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }    #T_0b9c650a_704b_11ea_a9bb_3af9d3abd3acrow5_col3 {
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }    #T_0b9c650a_704b_11ea_a9bb_3af9d3abd3acrow6_col3 {
#             background-color:  #157f3b;
#             color:  #f1f1f1;
# ...

# %%
rapStatsAgg.sort_values('Average_Track_Popularity', ascending=False).style.format(format_dict).hide_index().background_gradient(subset='Average_Track_Popularity', cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_17ef439a_704b_11ea_a9bb_3af9d3abd3acrow0_col2 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_17ef439a_704b_11ea_a9bb_3af9d3abd3acrow1_col2 {
#             background-color:  #440981;
#             color:  #f1f1f1;
#         }    #T_17ef439a_704b_11ea_a9bb_3af9d3abd3acrow2_col2 {
#             background-color:  #440a82;
#             color:  #f1f1f1;
#         }    #T_17ef439a_704b_11ea_a9bb_3af9d3abd3acrow3_col2 {
#             background-color:  #481084;
#             color:  #f1f1f1;
#         }    #T_17ef439a_704b_11ea_a9bb_3af9d3abd3acrow4_col2 {
#             background-color:  #4f1d8b;
#             color:  #f1f1f1;
#         }    #T_17ef439a_704b_11ea_a9bb_3af9d3abd3acrow5_col2 {
#             background-color:  #53268f;
#             color:  #f1f1f1;
#         }    #T_17ef439a_704b_11ea_a9bb_3af9d3abd3acrow6_col2 {
#             background-color:  #705eaa;
#             color:  #f1f1f1;
# ...

# %%
rapStatsAgg.sort_values('Playlist_Followers', ascending=False).style.format(format_dict).hide_index().background_gradient(subset='Playlist_Followers', cmap='Set3')
# Out:
# <style  type="text/css" >
#     #T_1d5685d2_704b_11ea_a9bb_3af9d3abd3acrow0_col1 {
#             background-color:  #ffed6f;
#             color:  #000000;
#         }    #T_1d5685d2_704b_11ea_a9bb_3af9d3abd3acrow1_col1 {
#             background-color:  #b3de69;
#             color:  #000000;
#         }    #T_1d5685d2_704b_11ea_a9bb_3af9d3abd3acrow2_col1 {
#             background-color:  #fdb462;
#             color:  #000000;
#         }    #T_1d5685d2_704b_11ea_a9bb_3af9d3abd3acrow3_col1 {
#             background-color:  #bebada;
#             color:  #000000;
#         }    #T_1d5685d2_704b_11ea_a9bb_3af9d3abd3acrow4_col1 {
#             background-color:  #bebada;
#             color:  #000000;
#         }    #T_1d5685d2_704b_11ea_a9bb_3af9d3abd3acrow5_col1 {
#             background-color:  #bebada;
#             color:  #000000;
#         }    #T_1d5685d2_704b_11ea_a9bb_3af9d3abd3acrow6_col1 {
#             background-color:  #ffffb3;
#             color:  #000000;
# ...

# %%
plt.figure(figsize=(5, 5))

rapAgg_chart = sns.scatterplot(x='Average_Artist_Popularity',
                        y='Average_Total_Playlists',
                        data=rapStatsAgg).set_title('Playlist Aggregation: Playlist Followers vs. Artist Popularity')
plt.show()

rapAgg_chart2 = sns.scatterplot(x='Playlist_Followers',
                        y='Average_Total_Playlists',
                        data=rapStatsAgg).set_title('Playlist Aggregation: Playlist Followers vs. Release To On')
plt.show()

# %% [markdown]
# # RapCaviar Path

# %%
rapCaviarOverlap = rap.loc[rap.RapCaviar==1]
rapCaviarOverlap = rapCaviarOverlap[rapCaviarOverlap['Days_On_RapCaviar'].isin([0.0])]

hotHitsNZOverlapRC = rapCaviarOverlap['Hot_Hits_New_Zealand'].value_counts(normalize=True)
hotHitsNZOverlapRC = 1 - hotHitsNZOverlapRC[0]

hotHitsNZTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hot_Hits_New_Zealand'].notnull()]
hotHitsNZTimeGapRC = hotHitsNZTimeGapRC['Days_On_Hot_Hits_New_Zealand'].mean()

hipHopMixOverlapRC = rapCaviarOverlap['Hip_Hop_Mix'].value_counts(normalize=True)
hipHopMixOverlapRC = 1 - hipHopMixOverlapRC[0]

hipHopMixTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hip_Hop_Mix'].notnull()]
hipHopMixTimeGapRC = hipHopMixTimeGapRC['Days_On_Hip_Hop_Mix'].mean()

internetPeopleOverlapRC = rapCaviarOverlap['Internet_People'].value_counts(normalize=True)
internetPeopleOverlapRC = 1 - internetPeopleOverlapRC[0]

internetPeopleTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Internet_People'].notnull()]
internetPeopleTimeGapRC = internetPeopleTimeGapRC['Days_On_Internet_People'].mean()

newMusicNowOverlapRC = rapCaviarOverlap['New_Music_Now'].value_counts(normalize=True)
newMusicNowOverlapRC = 1 - newMusicNowOverlapRC[0]

newMusicNowTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_New_Music_Now'].notnull()]
newMusicNowTimeGapRC = newMusicNowTimeGapRC['Days_On_New_Music_Now'].mean()

afroBashmentOverlapRC = rapCaviarOverlap['Afro_Bashment'].value_counts(normalize=True)
afroBashmentOverlapRC = 1 - afroBashmentOverlapRC[0]

afroBashmentTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Afro_Bashment'].notnull()]
afroBashmentTimeGapRC = afroBashmentTimeGapRC['Days_On_Afro_Bashment'].mean()

urbanFlavourOverlapRC = rapCaviarOverlap['Urban_Flavour'].value_counts(normalize=True)
urbanFlavourOverlapRC = 1 - urbanFlavourOverlapRC[0]

urbanFlavourTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Urban_Flavour'].notnull()]
urbanFlavourTimeGapRC = urbanFlavourTimeGapRC['Days_On_Urban_Flavour'].mean()

treinoOverlapRC = rapCaviarOverlap['Treino_Hip-Hop'].value_counts(normalize=True)
treinoOverlapRC = 1 - treinoOverlapRC[0]

treinoTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Treino_Hip-Hop'].notnull()]
treinoTimeGapRC = treinoTimeGapRC['Days_On_Treino_Hip-Hop'].mean()

beatsRhymesOverlapRC = rapCaviarOverlap['Beats_&_Rhymes'].value_counts(normalize=True)
beatsRhymesOverlapRC = 1 - beatsRhymesOverlapRC[0]

beatsRhymesTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Beats_&_Rhymes'].notnull()]
beatsRhymesTimeGapRC = beatsRhymesTimeGapRC['Days_On_Beats_&_Rhymes'].mean()

hipHopYogaOverlapRC = rapCaviarOverlap['Hip-Hop_Yoga'].value_counts(normalize=True)
hipHopYogaOverlapRC = 1 - hipHopYogaOverlapRC[0]

hipHopYogaTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hip-Hop_Yoga'].notnull()]
hipHopYogaTimeGapRC = hipHopYogaTimeGapRC['Days_On_Hip-Hop_Yoga'].mean()

hipHopFavOverlapRC = rapCaviarOverlap['Hip-Hop_Favourites'].value_counts(normalize=True)
hipHopFavOverlapRC = 1 - hipHopFavOverlapRC[0]

hipHopFavTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hip-Hop_Favourites'].notnull()]
hipHopFavTimeGapRC = hipHopFavTimeGapRC['Days_On_Hip-Hop_Favourites'].mean()

hotHipHopOverlapRC = rapCaviarOverlap['Hot_Hip_Hop'].value_counts(normalize=True)
hotHipHopOverlapRC = 1 - hotHipHopOverlapRC[0]

hotHipHopTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hot_Hip_Hop'].notnull()]
hotHipHopTimeGapRC = hotHipHopTimeGapRC['Days_On_Hot_Hip_Hop'].mean()

a1HipHopOverlapRC = rapCaviarOverlap['A1_Hip-Hop'].value_counts(normalize=True)
a1HipHopOverlapRC = 1 - a1HipHopOverlapRC[0]

a1HipHopTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_A1_Hip-Hop'].notnull()]
a1HipHopTimeGapRC = a1HipHopTimeGapRC['Days_On_A1_Hip-Hop'].mean()

stateOfMindOverlapRC = rapCaviarOverlap['State_of_Mind'].value_counts(normalize=True)
stateOfMindOverlapRC = 1 - stateOfMindOverlapRC[0]

stateOfMindTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_State_of_Mind'].notnull()]
stateOfMindTimeGapRC = stateOfMindTimeGapRC['Days_On_State_of_Mind'].mean()

rnbRightNowOverlapRC = rapCaviarOverlap['R&B_Right_Now'].value_counts(normalize=True)
rnbRightNowOverlapRC = 1 - rnbRightNowOverlapRC[0]

rnbRightNowTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_R&B_Right_Now'].notnull()]
rnbRightNowTimeGapRC = rnbRightNowTimeGapRC['Days_On_R&B_Right_Now'].mean()

spilledInkOverlapRC = rapCaviarOverlap['Spilled_Ink'].value_counts(normalize=True)
spilledInkOverlapRC = 1 - spilledInkOverlapRC[0]

spilledInkTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Spilled_Ink'].notnull()]
spilledInkTimeGapRC = spilledInkTimeGapRC['Days_On_Spilled_Ink'].mean()

antiPopOverlapRC = rapCaviarOverlap['Anti_Pop'].value_counts(normalize=True)
antiPopOverlapRC = 1 - antiPopOverlapRC[0]

antiPopTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Anti_Pop'].notnull()]
antiPopTimeGapRC = antiPopTimeGapRC['Days_On_Anti_Pop'].mean()

cloutCultureOverlapRC = rapCaviarOverlap['Clout_Culture'].value_counts(normalize=True)
cloutCultureOverlapRC = 1 - cloutCultureOverlapRC[0]

cloutCultureTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Clout_Culture'].notnull()]
cloutCultureTimeGapRC = cloutCultureTimeGapRC['Days_On_Clout_Culture'].mean()

swagOverlapRC = rapCaviarOverlap['Swag!'].value_counts(normalize=True)
swagOverlapRC = 1 - swagOverlapRC[0]

swagTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Swag!'].notnull()]
swagTimeGapRC = swagTimeGapRC['Days_On_Swag!'].mean()

altHipHopOverlapRC = rapCaviarOverlap['Alternative_Hip_Hop'].value_counts(normalize=True)
altHipHopOverlapRC = 1 - altHipHopOverlapRC[0]

altHipHopTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Alternative_Hip_Hop'].notnull()]
altHipHopTimeGapRC = altHipHopTimeGapRC['Days_On_Alternative_Hip_Hop'].mean()

whoWeBeOverlapRC = rapCaviarOverlap['Who_We_Be'].value_counts(normalize=True)
whoWeBeOverlapRC = 1 - whoWeBeOverlapRC[0]

whoWeBeTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Who_We_Be'].notnull()]
whoWeBeTimeGapRC = whoWeBeTimeGapRC['Days_On_Who_We_Be'].mean()

hipHopMixtapeOverlapRC = rapCaviarOverlap['Hip-Hop_Mixtape'].value_counts(normalize=True)
hipHopMixtapeOverlapRC = 1 - hipHopMixtapeOverlapRC[0]

hipHopMixtapeTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hip-Hop_Mixtape'].notnull()]
hipHopMixtapeTimeGapRC = hipHopMixtapeTimeGapRC['Days_On_Hip-Hop_Mixtape'].mean()

rapUKOverlapRC = rapCaviarOverlap['Rap_UK'].value_counts(normalize=True)
rapUKOverlapRC = 1 - rapUKOverlapRC[0]

rapUkTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Rap_UK'].notnull()]
rapUkTimeGapRC = rapUkTimeGapRC['Days_On_Rap_UK'].mean()

caliFireOverlapRC = rapCaviarOverlap['Cali_Fire'].value_counts(normalize=True)
caliFireOverlapRC = 1 - caliFireOverlapRC[0]

caliFireTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Cali_Fire'].notnull()]
caliFireTimeGapRC = caliFireTimeGapRC['Days_On_Cali_Fire'].mean()

mindRightOverlapRC = rapCaviarOverlap['Mind_Right'].value_counts(normalize=True)
mindRightOverlapRC = 1 - mindRightOverlapRC[0]

mindRightTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Mind_Right'].notnull()]
mindRightTimeGapRC = mindRightTimeGapRC['Days_On_Mind_Right'].mean()

lockedInOverlapRC = rapCaviarOverlap['Locked_In'].value_counts(normalize=True)
lockedInOverlapRC = 1 - lockedInOverlapRC[0]

lockedInTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Locked_In'].notnull()]
lockedInTimeGapRC = lockedInTimeGapRC['Days_On_Locked_In'].mean()

theNewnessOverlapRC = rapCaviarOverlap['The_Newness'].value_counts(normalize=True)
theNewnessOverlapRC = 1 - theNewnessOverlapRC[0]

theNewnessTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_The_Newness'].notnull()]
theNewnessTimeGapRC = theNewnessTimeGapRC['Days_On_The_Newness'].mean()

shishaLoungeOverlapRC = rapCaviarOverlap['Shisha_Lounge'].value_counts(normalize=True)
shishaLoungeOverlapRC = 1 - shishaLoungeOverlapRC[0]

shishaLoungeTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Shisha_Lounge'].notnull()]
shishaLoungeTimeGapRC = shishaLoungeTimeGapRC['Days_On_Shisha_Lounge'].mean()

singledOutOverlapRC = rapCaviarOverlap['Singled_Out'].value_counts(normalize=True)
singledOutOverlapRC = 1 - singledOutOverlapRC[0]

singledOutTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Singled_Out'].notnull()]
singledOutTimeGapRC = singledOutTimeGapRC['Days_On_Singled_Out'].mean()

hipHopCentralOverlapRC = rapCaviarOverlap['Hip-Hop_Central'].value_counts(normalize=True)
hipHopCentralOverlapRC = 1 - hipHopCentralOverlapRC[0]

hipHopCentralTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hip-Hop_Central'].notnull()]
hipHopCentralTimeGapRC = hipHopCentralTimeGapRC['Days_On_Hip-Hop_Central'].mean()

topHitsNLOverlapRC = rapCaviarOverlap['Top_Hits_NL'].value_counts(normalize=True)
topHitsNLOverlapRC = 1 - topHitsNLOverlapRC[0]

topHitsNlTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Top_Hits_NL'].notnull()]
topHitsNlTimeGapRC = topHitsNlTimeGapRC['Days_On_Top_Hits_NL'].mean()

grimeShutdownOverlapRC = rapCaviarOverlap['Grime_Shutdown'].value_counts(normalize=True)
grimeShutdownOverlapRC = 1 - grimeShutdownOverlapRC[0]

grimeShutdownTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Grime_Shutdown'].notnull()]
grimeShutdownTimeGapRC = grimeShutdownTimeGapRC['Days_On_Grime_Shutdown'].mean()

offTheStrengthOverlapRC = rapCaviarOverlap['Off_The_Strength'].value_counts(normalize=True)
offTheStrengthOverlapRC = 1 - offTheStrengthOverlapRC[0]

offTheStrengthTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Off_The_Strength'].notnull()]
offTheStrengthTimeGapRC = offTheStrengthTimeGapRC['Days_On_Off_The_Strength'].mean()

realestDownSouthOverlapRC = rapCaviarOverlap['The_Realest_Down_South'].value_counts(normalize=True)
realestDownSouthOverlapRC = 1 - realestDownSouthOverlapRC[0]

realestDownSouthTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_The_Realest_Down_South'].notnull()]
realestDownSouthTimeGapRC = realestDownSouthTimeGapRC['Days_On_The_Realest_Down_South'].mean()

mellowBarsOverlapRC = rapCaviarOverlap['Mellow_Bars'].value_counts(normalize=True)
mellowBarsOverlapRC = 1 - mellowBarsOverlapRC[0]

mellowBarsTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Mellow_Bars'].notnull()]
mellowBarsTimeGapRC = mellowBarsTimeGapRC['Days_On_Mellow_Bars'].mean()

rapWorkoutOverlapRC = rapCaviarOverlap['Rap_Workout'].value_counts(normalize=True)
rapWorkoutOverlapRC = 1 - rapWorkoutOverlapRC[0]

rapWorkoutTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Rap_Workout'].notnull()]
rapWorkoutTimeGapRC = rapWorkoutTimeGapRC['Days_On_Rap_Workout'].mean()

bedroomJamsOverlapRC = rapCaviarOverlap['Bedroom_Jams'].value_counts(normalize=True)
bedroomJamsOverlapRC = 1 - bedroomJamsOverlapRC[0]

bedroomJamsTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Bedroom_Jams'].notnull()]
bedroomJamsTimeGapRC = bedroomJamsTimeGapRC['Days_On_Bedroom_Jams'].mean()

hotHitsAusOverlapRC = rapCaviarOverlap['Hot_Hits_Australia'].value_counts(normalize=True)
hotHitsAusOverlapRC = 1 - hotHitsAusOverlapRC[0]

hotHitsAusTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hot_Hits_Australia'].notnull()]
hotHitsAusTimeGapRC = hotHitsAusTimeGapRC['Days_On_Hot_Hits_Australia'].mean()

workoutTwerkoutOverlapRC = rapCaviarOverlap['Workout_Twerkout'].value_counts(normalize=True)
workoutTwerkoutOverlapRC = 1 - workoutTwerkoutOverlapRC[0]

workoutTwerkoutTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Workout_Twerkout'].notnull()]
workoutTwerkoutTimeGapRC = workoutTwerkoutTimeGapRC['Days_On_Workout_Twerkout'].mean()

channelXOverlapRC = rapCaviarOverlap['Channel_X'].value_counts(normalize=True)
channelXOverlapRC = 1 - channelXOverlapRC[0]

channelXTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Channel_X'].notnull()]
channelXTimeGapRC = channelXTimeGapRC['Days_On_Channel_X'].mean()

signedXoxoOverlapRC = rapCaviarOverlap['Signed_XOXO'].value_counts(normalize=True)
signedXoxoOverlapRC = 1 - signedXoxoOverlapRC[0]

signedXoxoTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Signed_XOXO'].notnull()]
signedXoxoTimeGapRC = signedXoxoTimeGapRC['Days_On_Signed_XOXO'].mean()

baeOverlapRC = rapCaviarOverlap['BAE'].value_counts(normalize=True)
baeOverlapRC = 1 - baeOverlapRC[0]

baeTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_BAE'].notnull()]
baeTimeGapRC = baeTimeGapRC['Days_On_BAE'].mean()

lswOverlapRC = rapCaviarOverlap['Love,_Sex,_&_Water'].value_counts(normalize=True)
lswOverlapRC = 1 - lswOverlapRC[0]

lswTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Love,_Sex,_&_Water'].notnull()]
lswTimeGapRC = lswTimeGapRC['Days_On_Love,_Sex,_&_Water'].mean()

hotRhythmicOverlapRC = rapCaviarOverlap['Hot_Rhythmic'].value_counts(normalize=True)
hotRhythmicOverlapRC = 1 - hotRhythmicOverlapRC[0]

hotRhythmicTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hot_Rhythmic'].notnull()]
hotRhythmicTimeGapRC = hotRhythmicTimeGapRC['Days_On_Hot_Rhythmic'].mean()

topHitsGermanyOverlapRC = rapCaviarOverlap['Top_Hits_Deutschland'].value_counts(normalize=True)
topHitsGermanyOverlapRC = 1 - topHitsGermanyOverlapRC[0]

topHitsGermanyTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Top_Hits_Deutschland'].notnull()]
topHitsGermanyTimeGapRC = topHitsGermanyTimeGapRC['Days_On_Top_Hits_Deutschland'].mean()

hotHitsUkOverlapRC = rapCaviarOverlap['Hot_Hits_UK'].value_counts(normalize=True)
hotHitsUkOverlapRC = 1 - hotHitsUkOverlapRC[0]

hotHitsUkTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Hot_Hits_UK'].notnull()]
hotHitsUkTimeGapRC = hotHitsUkTimeGapRC['Days_On_Hot_Hits_UK'].mean()

mostNecessaryOverlapRC = rapCaviarOverlap['Most_Necessary'].value_counts(normalize=True)
mostNecessaryOverlapRC = 1 - mostNecessaryOverlapRC[0]

mostNecessaryTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Most_Necessary'].notnull()]
mostNecessaryTimeGapRC = mostNecessaryTimeGapRC['Days_On_Most_Necessary'].mean()

getTurntOverlapRC = rapCaviarOverlap['Get_Turnt'].value_counts(normalize=True)
getTurntOverlapRC = 1 - getTurntOverlapRC[0]

getTurntTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Get_Turnt'].notnull()]
getTurntTimeGapRC = getTurntTimeGapRC['Days_On_Get_Turnt'].mean()

beastModeOverlapRC = rapCaviarOverlap['Beast_Mode'].value_counts(normalize=True)
beastModeOverlapRC = 1 - beastModeOverlapRC[0]

beastModeTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Beast_Mode'].notnull()]
beastModeTimeGapRC = beastModeTimeGapRC['Days_On_Beast_Mode'].mean()

powerWorkoutOverlapRC = rapCaviarOverlap['Power_Workout'].value_counts(normalize=True)
powerWorkoutOverlapRC = 1 - powerWorkoutOverlapRC[0]

powerWorkoutTimeGapRC = rapCaviarOverlap.loc[rapCaviarOverlap['Days_On_Power_Workout'].notnull()]
powerWorkoutTimeGapRC = powerWorkoutTimeGapRC['Days_On_Power_Workout'].mean()

rapCavTimeGapRC = 0

print('Number of New Tracks Appeared On RapCaviar:', rapCaviarOverlap['Track'].count())
print('Overlap With Other Playlists:')
print('Hot Hits NZ Overlap: {:.2%}'.format(hotHitsNZOverlapRC))
print('Hip Hop Mix Overlap: {:.2%}'.format(hipHopMixOverlapRC))
print('Internet People Overlap: {:.2%}'.format(internetPeopleOverlapRC))
print('New Music Now Overlap: {:.2%}'.format(newMusicNowOverlapRC))
print('Afro Bashment Overlap: {:.2%}'.format(afroBashmentOverlapRC))
print('Urban Flavour Overlap: {:.2%}'.format(urbanFlavourOverlapRC))
print('Treino Hip Hop Overlap: {:.2%}'.format(treinoOverlapRC))
print('Beats & Rhymes Overlap: {:.2%}'.format(beatsRhymesOverlapRC))
print('Hip Hop Yoga Overlap: {:.2%}'.format(hipHopYogaOverlapRC))
print('Hip Hop Favourites Overlap: {:.2%}'.format(hipHopFavOverlapRC))
print('Hot Hip Hop Overlap: {:.2%}'.format(hotHipHopOverlapRC))
print('A1 Hip Hop Overlap: {:.2%}'.format(a1HipHopOverlapRC))
print('State of Mind Overlap: {:.2%}'.format(stateOfMindOverlapRC))
print('R&B Right Now Overlap: {:.2%}'.format(rnbRightNowOverlapRC))
print('Spilled Ink Overlap: {:.2%}'.format(spilledInkOverlapRC))
print('Anti Pop Overlap: {:.2%}'.format(antiPopOverlapRC))
print('Clout Culture Overlap: {:.2%}'.format(cloutCultureOverlapRC))
print('Swag! Overlap: {:.2%}'.format(swagOverlapRC))
print('Alternative Hip Hop Overlap: {:.2%}'.format(altHipHopOverlapRC))
print('Who We Be Overlap: {:.2%}'.format(whoWeBeOverlapRC))
print('Hip Hop Mixtape Overlap: {:.2%}'.format(hipHopMixtapeOverlapRC))
print('Rap UK Overlap: {:.2%}'.format(rapUKOverlapRC))
print('Cali Fire Overlap: {:.2%}'.format(caliFireOverlapRC))
print('Mind Right Overlap: {:.2%}'.format(mindRightOverlapRC))
print('Locked In Overlap: {:.2%}'.format(lockedInOverlapRC))
print('The Newness Overlap: {:.2%}'.format(theNewnessOverlapRC))
print('Shisha Lounge Overlap: {:.2%}'.format(shishaLoungeOverlapRC))
print('Singled Out Overlap: {:.2%}'.format(singledOutOverlapRC))
print('Hip Hop Central Overlap: {:.2%}'.format(hipHopCentralOverlapRC))
print('Top Hits NL Overlap: {:.2%}'.format(topHitsNLOverlapRC))
print('Grime Shutdown Overlap: {:.2%}'.format(grimeShutdownOverlapRC))
print('Off The Strength Overlap: {:.2%}'.format(offTheStrengthOverlapRC))
print('Realest Down South Overlap: {:.2%}'.format(realestDownSouthOverlapRC))
print('Mellow Bars Overlap: {:.2%}'.format(mellowBarsOverlapRC))
print('Rap Workout Overlap: {:.2%}'.format(rapWorkoutOverlapRC))
print('Bedroom Jams Overlap: {:.2%}'.format(bedroomJamsOverlapRC))
print('Hot Hits Australia Overlap: {:.2%}'.format(hotHitsAusOverlapRC))
print('Workout Twerkout Overlap: {:.2%}'.format(workoutTwerkoutOverlapRC))
print('Channel X Overlap: {:.2%}'.format(channelXOverlapRC))
print('Signed XOXO Overlap: {:.2%}'.format(signedXoxoOverlapRC))
print('BAE Overlap: {:.2%}'.format(baeOverlapRC))
print('Love, Sex, Water Overlap: {:.2%}'.format(lswOverlapRC))
print('Hot Rhythmic Overlap: {:.2%}'.format(hotRhythmicOverlapRC))
print('Top Hits Germany Overlap: {:.2%}'.format(topHitsGermanyOverlapRC))
print('Hot Hits UK Overlap: {:.2%}'.format(hotHitsUkOverlapRC))
print('Most Necessary Overlap: {:.2%}'.format(mostNecessaryOverlapRC))
print('Get Turnt Overlap: {:.2%}'.format(getTurntOverlapRC))
print('Beast Mode Overlap: {:.2%}'.format(beastModeOverlapRC))
print('Power Workout Overlap: {:.2%}'.format(powerWorkoutOverlapRC))
# Out:
# Number of New Tracks Appeared On RapCaviar: 32
# Overlap With Other Playlists:
# Hot Hits NZ Overlap: 0.00%
# Hip Hop Mix Overlap: 3.12%
# Internet People Overlap: 9.38%
# New Music Now Overlap: 6.25%
# Afro Bashment Overlap: 0.00%
# Urban Flavour Overlap: 6.25%
# Treino Hip Hop Overlap: 0.00%
# Beats & Rhymes Overlap: 21.88%
# Hip Hop Yoga Overlap: 0.00%
# Hip Hop Favourites Overlap: 0.00%
# Hot Hip Hop Overlap: 12.50%
# A1 Hip Hop Overlap: 18.75%
# State of Mind Overlap: 21.88%
# R&B Right Now Overlap: 3.12%
# Spilled Ink Overlap: 0.00%
# Anti Pop Overlap: 0.00%
# Clout Culture Overlap: 6.25%
# Swag! Overlap: 0.00%
# Alternative Hip Hop Overlap: 0.00%
# Who We Be Overlap: 9.38%
# Hip Hop Mixtape Overlap: 9.38%
# Rap UK Overlap: 0.00%
# Cali Fire Overlap: 3.12%
# Mind Right Overlap: 0.00%
# Locked In Overlap: 0.00%
# The Newness Overlap: 0.00%
# Shisha Lounge Overlap: 9.38%
# Singled Out Overlap: 6.25%
# Hip Hop Central Overlap: 65.62%
# Top Hits NL Overlap: 0.00%
# ...

# %% [markdown]
# # RapCaviar Overlap Table

# %%
rapCaviarOverlapDF = rapStatsAgg.iloc[:,0:2].sort_values('Playlist_Followers', ascending=False)
rapCaviarOverlapDF
rapCaviarOverlapDF['Overlap'] =  (1, beastModeOverlapRC, getTurntOverlapRC, powerWorkoutOverlapRC,
                                      hotHitsUkOverlapRC, mostNecessaryOverlapRC, topHitsGermanyOverlapRC, hotRhythmicOverlapRC,
                                      lswOverlapRC, baeOverlapRC, signedXoxoOverlapRC, channelXOverlapRC,
                                      workoutTwerkoutOverlapRC, hotHitsAusOverlapRC, bedroomJamsOverlapRC, mellowBarsOverlapRC,
                                      realestDownSouthOverlapRC, offTheStrengthOverlapRC, grimeShutdownOverlapRC, topHitsNLOverlapRC,
                                      hipHopCentralOverlapRC, singledOutOverlapRC, shishaLoungeOverlapRC, theNewnessOverlapRC, 
                                      lockedInOverlapRC, mindRightOverlapRC, caliFireOverlapRC, rapUKOverlapRC,
                                      hipHopMixtapeOverlapRC, whoWeBeOverlapRC, altHipHopOverlapRC, swagOverlapRC,
                                      cloutCultureOverlapRC, antiPopOverlapRC, spilledInkOverlapRC, rnbRightNowOverlapRC,
                                      stateOfMindOverlapRC, a1HipHopOverlapRC, hotHipHopOverlapRC, hipHopYogaOverlapRC,
                                      beatsRhymesOverlapRC, treinoOverlapRC, urbanFlavourOverlapRC, afroBashmentOverlapRC, newMusicNowOverlapRC,
                                      internetPeopleOverlapRC, hipHopMixOverlapRC, hotHitsNZOverlapRC)
rapCaviarOverlapDF['Timegap'] =  (rapCavTimeGapRC, beastModeTimeGapRC, getTurntTimeGapRC, powerWorkoutTimeGapRC,
                                      hotHitsUkTimeGapRC, mostNecessaryTimeGapRC, topHitsGermanyTimeGapRC, hotRhythmicTimeGapRC,
                                      lswTimeGapRC, baeTimeGapRC, signedXoxoTimeGapRC, channelXTimeGapRC,
                                      workoutTwerkoutTimeGapRC, hotHitsAusTimeGapRC, bedroomJamsTimeGapRC, mellowBarsTimeGapRC,
                                      realestDownSouthTimeGapRC, offTheStrengthTimeGapRC, grimeShutdownTimeGapRC, topHitsNlTimeGapRC,
                                      hipHopCentralTimeGapRC, singledOutTimeGapRC, shishaLoungeTimeGapRC, theNewnessTimeGapRC, 
                                      lockedInTimeGapRC, mindRightTimeGapRC, caliFireTimeGapRC, rapUkTimeGapRC,
                                      hipHopMixtapeTimeGapRC, whoWeBeTimeGapRC, altHipHopTimeGapRC, swagTimeGapRC,
                                      cloutCultureTimeGapRC, antiPopTimeGapRC, spilledInkTimeGapRC, rnbRightNowTimeGapRC,
                                      stateOfMindTimeGapRC, a1HipHopTimeGapRC, hotHipHopTimeGapRC, hipHopYogaTimeGapRC,
                                      beatsRhymesTimeGapRC, treinoTimeGapRC, urbanFlavourTimeGapRC, afroBashmentTimeGapRC, newMusicNowTimeGapRC,
                                      internetPeopleTimeGapRC, hipHopMixTimeGapRC, hotHitsNZTimeGapRC)

rapCaviarOverlapDF.reset_index(drop=True)
format_dict_new_RC = {'Playlist Followers': '{:,}', 'Overlap':'{:.2%}', 'Timegap':'{:,.0f}'}
rapCaviarOverlapDF = rapCaviarOverlapDF[rapCaviarOverlapDF.Overlap != 0]
rapCaviarOverlapDF = rapCaviarOverlapDF[rapCaviarOverlapDF.Overlap != 1]
rapCaviarOverlapDF.columns = rapCaviarOverlapDF.columns.str.replace('_', ' ')
rapCaviarOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new_RC).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('RapCaviar Target Playlist: Overlap')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-820a97e0b220> in <module>
#      12                                       stateOfMindOverlapRC, a1HipHopOverlapRC, hotHipHopOverlapRC, hipHopYogaOverlapRC,
#      13                                       beatsRhymesOverlapRC, treinoOverlapRC, urbanFlavourOverlapRC, afroBashmentOverlapRC, newMusicNowOverlapRC,
# ---> 14                                       internetPeopleOverlapRC, hipHopMixOverlapRC, hotHitsNZOverlapRC)
#      15 rapCaviarOverlapDF['Timegap'] =  (rapCavTimeGapRC, beastModeTimeGapRC, getTurntTimeGapRC, powerWorkoutTimeGapRC,
#      16                                       hotHitsUkTimeGapRC, mostNecessaryTimeGapRC, topHitsGermanyTimeGapRC, hotRhythmicTimeGapRC,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
# ...

# %% [markdown]
# # Beast Mode Path

# %%
beastModeOverlap = rap.loc[rap['Beast_Mode']==1]
beastModeOverlap = beastModeOverlap[beastModeOverlap['Days_On_Beast_Mode'].isin([0.0])]

hotHitsNZOverlapBM = beastModeOverlap['Hot_Hits_New_Zealand'].value_counts(normalize=True)
hotHitsNZOverlapBM = 1 - hotHitsNZOverlapBM[0]

hotHitsNZTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hot_Hits_New_Zealand'].notnull()]
hotHitsNZTimeGapBM = hotHitsNZTimeGapBM['Days_On_Hot_Hits_New_Zealand'].mean()

hipHopMixOverlapBM = beastModeOverlap['Hip_Hop_Mix'].value_counts(normalize=True)
hipHopMixOverlapBM = 1 - hipHopMixOverlapBM[0]

hipHopMixTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hip_Hop_Mix'].notnull()]
hipHopMixTimeGapBM = hipHopMixTimeGapBM['Days_On_Hip_Hop_Mix'].mean()

internetPeopleOverlapBM = beastModeOverlap['Internet_People'].value_counts(normalize=True)
internetPeopleOverlapBM = 1 - internetPeopleOverlapBM[0]

internetPeopleTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Internet_People'].notnull()]
internetPeopleTimeGapBM = internetPeopleTimeGapBM['Days_On_Internet_People'].mean()

newMusicNowOverlapBM = beastModeOverlap['New_Music_Now'].value_counts(normalize=True)
newMusicNowOverlapBM = 1 - newMusicNowOverlapBM[0]

newMusicNowTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_New_Music_Now'].notnull()]
newMusicNowTimeGapBM = newMusicNowTimeGapBM['Days_On_New_Music_Now'].mean()

afroBashmentOverlapBM = beastModeOverlap['Afro_Bashment'].value_counts(normalize=True)
afroBashmentOverlapBM = 1 - afroBashmentOverlapBM[0]

afroBashmentTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Afro_Bashment'].notnull()]
afroBashmentTimeGapBM = afroBashmentTimeGapBM['Days_On_Afro_Bashment'].mean()

urbanFlavourOverlapBM = beastModeOverlap['Urban_Flavour'].value_counts(normalize=True)
urbanFlavourOverlapBM = 1 - urbanFlavourOverlapBM[0]

urbanFlavourTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Urban_Flavour'].notnull()]
urbanFlavourTimeGapBM = urbanFlavourTimeGapBM['Days_On_Urban_Flavour'].mean()

beatsRhymesOverlapBM = beastModeOverlap['Beats_&_Rhymes'].value_counts(normalize=True)
beatsRhymesOverlapBM = 1 - beatsRhymesOverlapBM[0]

beatsRhymesTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Beats_&_Rhymes'].notnull()]
beatsRhymesTimeGapBM = beatsRhymesTimeGapBM['Days_On_Beats_&_Rhymes'].mean()

hipHopYogaOverlapBM = beastModeOverlap['Hip-Hop_Yoga'].value_counts(normalize=True)
hipHopYogaOverlapBM = 1 - hipHopYogaOverlapBM[0]

hipHopYogaTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hip-Hop_Yoga'].notnull()]
hipHopYogaTimeGapBM = hipHopYogaTimeGapBM['Days_On_Hip-Hop_Yoga'].mean()

hotHipHopOverlapBM = beastModeOverlap['Hot_Hip_Hop'].value_counts(normalize=True)
hotHipHopOverlapBM = 1 - hotHipHopOverlapBM[0]

hotHipHopTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hot_Hip_Hop'].notnull()]
hotHipHopTimeGapBM = hotHipHopTimeGapBM['Days_On_Hot_Hip_Hop'].mean()

a1HipHopOverlapBM = beastModeOverlap['A1_Hip-Hop'].value_counts(normalize=True)
a1HipHopOverlapBM = 1 - a1HipHopOverlapBM[0]

a1HipHopTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_A1_Hip-Hop'].notnull()]
a1HipHopTimeGapBM = a1HipHopTimeGapBM['Days_On_A1_Hip-Hop'].mean()

stateOfMindOverlapBM = beastModeOverlap['State_of_Mind'].value_counts(normalize=True)
stateOfMindOverlapBM = 1 - stateOfMindOverlapBM[0]

stateOfMindTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_State_of_Mind'].notnull()]
stateOfMindTimeGapBM = stateOfMindTimeGapBM['Days_On_State_of_Mind'].mean()

rnbRightNowOverlapBM = beastModeOverlap['R&B_Right_Now'].value_counts(normalize=True)
rnbRightNowOverlapBM = 1 - rnbRightNowOverlapBM[0]

rnbRightNowTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_R&B_Right_Now'].notnull()]
rnbRightNowTimeGapBM = rnbRightNowTimeGapBM['Days_On_R&B_Right_Now'].mean()

spilledInkOverlapBM = beastModeOverlap['Spilled_Ink'].value_counts(normalize=True)
spilledInkOverlapBM = 1 - spilledInkOverlapBM[0]

spilledInkTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Spilled_Ink'].notnull()]
spilledInkTimeGapBM = spilledInkTimeGapBM['Days_On_Spilled_Ink'].mean()

antiPopOverlapBM = beastModeOverlap['Anti_Pop'].value_counts(normalize=True)
antiPopOverlapBM = 1 - antiPopOverlapBM[0]

antiPopTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Anti_Pop'].notnull()]
antiPopTimeGapBM = antiPopTimeGapBM['Days_On_Anti_Pop'].mean()

cloutCultureOverlapBM = beastModeOverlap['Clout_Culture'].value_counts(normalize=True)
cloutCultureOverlapBM = 1 - cloutCultureOverlapBM[0]

cloutCultureTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Clout_Culture'].notnull()]
cloutCultureTimeGapBM = cloutCultureTimeGapBM['Days_On_Clout_Culture'].mean()

swagOverlapBM = beastModeOverlap['Swag!'].value_counts(normalize=True)
swagOverlapBM = 1 - swagOverlapBM[0]

swagTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Swag!'].notnull()]
swagTimeGapBM = swagTimeGapBM['Days_On_Swag!'].mean()

altHipHopOverlapBM = beastModeOverlap['Alternative_Hip_Hop'].value_counts(normalize=True)
altHipHopOverlapBM = 1 - altHipHopOverlapBM[0]

altHipHopTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Alternative_Hip_Hop'].notnull()]
altHipHopTimeGapBM = altHipHopTimeGapBM['Days_On_Alternative_Hip_Hop'].mean()

whoWeBeOverlapBM = beastModeOverlap['Who_We_Be'].value_counts(normalize=True)
whoWeBeOverlapBM = whoWeBeOverlapBM[1]
# whoWeBeOverlapBM = 1 - whoWeBeOverlapBM[0]

whoWeBeTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Who_We_Be'].notnull()]
whoWeBeTimeGapBM = whoWeBeTimeGapBM['Days_On_Who_We_Be'].mean()

hipHopMixtapeOverlapBM = beastModeOverlap['Hip-Hop_Mixtape'].value_counts(normalize=True)
hipHopMixtapeOverlapBM = hipHopMixtapeOverlapBM[1]
# hipHopMixtapeOverlapBM = 1 - hipHopMixtapeOverlapBM[0]

hipHopMixtapeTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hip-Hop_Mixtape'].notnull()]
hipHopMixtapeTimeGapBM = hipHopMixtapeTimeGapBM['Days_On_Hip-Hop_Mixtape'].mean()

rapUKOverlapBM = beastModeOverlap['Rap_UK'].value_counts(normalize=True)
rapUKOverlapBM = 1 - rapUKOverlapBM[0]

rapUkTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Rap_UK'].notnull()]
rapUkTimeGapBM = rapUkTimeGapBM['Days_On_Rap_UK'].mean()

caliFireOverlapBM = beastModeOverlap['Cali_Fire'].value_counts(normalize=True)
caliFireOverlapBM = 1 - caliFireOverlapBM[0]

caliFireTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Cali_Fire'].notnull()]
caliFireTimeGapBM = caliFireTimeGapBM['Days_On_Cali_Fire'].mean()

mindRightOverlapBM = beastModeOverlap['Mind_Right'].value_counts(normalize=True)
mindRightOverlapBM = 1 - mindRightOverlapBM[0]

mindRightTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Mind_Right'].notnull()]
mindRightTimeGapBM = mindRightTimeGapBM['Days_On_Mind_Right'].mean()

lockedInOverlapBM = beastModeOverlap['Locked_In'].value_counts(normalize=True)
lockedInOverlapBM = 1 - lockedInOverlapBM[0]

lockedInTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Locked_In'].notnull()]
lockedInTimeGapBM = lockedInTimeGapBM['Days_On_Locked_In'].mean()

theNewnessOverlapBM = beastModeOverlap['The_Newness'].value_counts(normalize=True)
theNewnessOverlapBM = 1 - theNewnessOverlapBM[0]

theNewnessTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_The_Newness'].notnull()]
theNewnessTimeGapBM = theNewnessTimeGapBM['Days_On_The_Newness'].mean()

shishaLoungeOverlapBM = beastModeOverlap['Shisha_Lounge'].value_counts(normalize=True)
shishaLoungeOverlapBM = shishaLoungeOverlapBM[1]
# shishaLoungeOverlapBM = 1 - shishaLoungeOverlapBM[0]

shishaLoungeTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Shisha_Lounge'].notnull()]
shishaLoungeTimeGapBM = shishaLoungeTimeGapBM['Days_On_Shisha_Lounge'].mean()

singledOutOverlapBM = beastModeOverlap['Singled_Out'].value_counts(normalize=True)
singledOutOverlapBM = 1 - singledOutOverlapBM[0]

singledOutTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Singled_Out'].notnull()]
singledOutTimeGapBM = singledOutTimeGapBM['Days_On_Singled_Out'].mean()

hipHopCentralOverlapBM = beastModeOverlap['Hip-Hop_Central'].value_counts(normalize=True)
hipHopCentralOverlapBM = hipHopCentralOverlapBM[1]
# hipHopCentralOverlapBM = 1 - hipHopCentralOverlapBM[0]

hipHopCentralTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hip-Hop_Central'].notnull()]
hipHopCentralTimeGapBM = hipHopCentralTimeGapBM['Days_On_Hip-Hop_Central'].mean()

topHitsNLOverlapBM = beastModeOverlap['Top_Hits_NL'].value_counts(normalize=True)
topHitsNLOverlapBM = 1 - topHitsNLOverlapBM[0]

topHitsNlTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Top_Hits_NL'].notnull()]
topHitsNlTimeGapBM = topHitsNlTimeGapBM['Days_On_Top_Hits_NL'].mean()

grimeShutdownOverlapBM = beastModeOverlap['Grime_Shutdown'].value_counts(normalize=True)
grimeShutdownOverlapBM = 1 - grimeShutdownOverlapBM[0]

grimeShutdownTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Grime_Shutdown'].notnull()]
grimeShutdownTimeGapBM = grimeShutdownTimeGapBM['Days_On_Grime_Shutdown'].mean()

offTheStrengthOverlapBM = beastModeOverlap['Off_The_Strength'].value_counts(normalize=True)
offTheStrengthOverlapBM = 1 - offTheStrengthOverlapBM[0]

offTheStrengthTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Off_The_Strength'].notnull()]
offTheStrengthTimeGapBM = offTheStrengthTimeGapBM['Days_On_Off_The_Strength'].mean()

realestDownSouthOverlapBM = beastModeOverlap['The_Realest_Down_South'].value_counts(normalize=True)
realestDownSouthOverlapBM = 1 - realestDownSouthOverlapBM[0]

realestDownSouthTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_The_Realest_Down_South'].notnull()]
realestDownSouthTimeGapBM = realestDownSouthTimeGapBM['Days_On_The_Realest_Down_South'].mean()

mellowBarsOverlapBM = beastModeOverlap['Mellow_Bars'].value_counts(normalize=True)
mellowBarsOverlapBM = 1 - mellowBarsOverlapBM[0]

mellowBarsTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Mellow_Bars'].notnull()]
mellowBarsTimeGapBM = mellowBarsTimeGapBM['Days_On_Mellow_Bars'].mean()

bedroomJamsOverlapBM = beastModeOverlap['Bedroom_Jams'].value_counts(normalize=True)
bedroomJamsOverlapBM = 1 - bedroomJamsOverlapBM[0]

bedroomJamsTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Bedroom_Jams'].notnull()]
bedroomJamsTimeGapBM = bedroomJamsTimeGapBM['Days_On_Bedroom_Jams'].mean()

hotHitsAusOverlapBM = beastModeOverlap['Hot_Hits_Australia'].value_counts(normalize=True)
hotHitsAusOverlapBM = 1 - hotHitsAusOverlapBM[0]

hotHitsAusTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hot_Hits_Australia'].notnull()]
hotHitsAusTimeGapBM = hotHitsAusTimeGapBM['Days_On_Hot_Hits_Australia'].mean()

workoutTwerkoutOverlapBM = beastModeOverlap['Workout_Twerkout'].value_counts(normalize=True)
workoutTwerkoutOverlapBM = 1 - workoutTwerkoutOverlapBM[0]

workoutTwerkoutTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Workout_Twerkout'].notnull()]
workoutTwerkoutTimeGapBM = workoutTwerkoutTimeGapBM['Days_On_Workout_Twerkout'].mean()

channelXOverlapBM = beastModeOverlap['Channel_X'].value_counts(normalize=True)
channelXOverlapBM = 1 - channelXOverlapBM[0]

channelXTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Channel_X'].notnull()]
channelXTimeGapBM = channelXTimeGapBM['Days_On_Channel_X'].mean()

signedXoxoOverlapBM = beastModeOverlap['Signed_XOXO'].value_counts(normalize=True)
signedXoxoOverlapBM = 1 - signedXoxoOverlapBM[0]

signedXoxoTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Signed_XOXO'].notnull()]
signedXoxoTimeGapBM = signedXoxoTimeGapBM['Days_On_Signed_XOXO'].mean()

baeOverlapBM = beastModeOverlap['BAE'].value_counts(normalize=True)
baeOverlapBM = 1 - baeOverlapBM[0]

baeTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_BAE'].notnull()]
baeTimeGapBM = baeTimeGapBM['Days_On_BAE'].mean()

lswOverlapBM = beastModeOverlap['Love,_Sex,_&_Water'].value_counts(normalize=True)
lswOverlapBM = 1 - lswOverlapBM[0]

lswTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Love,_Sex,_&_Water'].notnull()]
lswTimeGapBM = lswTimeGapBM['Days_On_Love,_Sex,_&_Water'].mean()

hotRhythmicOverlapBM = beastModeOverlap['Hot_Rhythmic'].value_counts(normalize=True)
hotRhythmicOverlapBM = 1 - hotRhythmicOverlapBM[0]

hotRhythmicTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hot_Rhythmic'].notnull()]
hotRhythmicTimeGapBM = hotRhythmicTimeGapBM['Days_On_Hot_Rhythmic'].mean()

topHitsGermanyOverlapBM = beastModeOverlap['Top_Hits_Deutschland'].value_counts(normalize=True)
topHitsGermanyOverlapBM = 1 - topHitsGermanyOverlapBM[0]

topHitsGermanyTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Top_Hits_Deutschland'].notnull()]
topHitsGermanyTimeGapBM = topHitsGermanyTimeGapBM['Days_On_Top_Hits_Deutschland'].mean()

hotHitsUkOverlapBM = beastModeOverlap['Hot_Hits_UK'].value_counts(normalize=True)
hotHitsUkOverlapBM = 1 - hotHitsUkOverlapBM[0]

hotHitsUkTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Hot_Hits_UK'].notnull()]
hotHitsUkTimeGapBM = hotHitsUkTimeGapBM['Days_On_Hot_Hits_UK'].mean()

mostNecessaryOverlapBM = beastModeOverlap['Most_Necessary'].value_counts(normalize=True)
mostNecessaryOverlapBM = 1 - mostNecessaryOverlapBM[0]

mostNecessaryTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Most_Necessary'].notnull()]
mostNecessaryTimeGapBM = mostNecessaryTimeGapBM['Days_On_Most_Necessary'].mean()

getTurntOverlapBM = beastModeOverlap['Get_Turnt'].value_counts(normalize=True)
getTurntOverlapBM = getTurntOverlapBM[1]
# getTurntOverlapBM = 1 - getTurntOverlapBM[0]

getTurntTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Get_Turnt'].notnull()]
getTurntTimeGapBM = getTurntTimeGapBM['Days_On_Get_Turnt'].mean()

beastModeTimeGapBM = 0

powerWorkoutOverlapBM = beastModeOverlap['Power_Workout'].value_counts(normalize=True)
powerWorkoutOverlapBM = 1 - powerWorkoutOverlapBM[0]

powerWorkoutTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_Power_Workout'].notnull()]
powerWorkoutTimeGapBM = powerWorkoutTimeGapBM['Days_On_Power_Workout'].mean()

rapCavOverlapBM = beastModeOverlap['RapCaviar'].value_counts(normalize=True)
rapCavOverlapBM = rapCavOverlapBM[1]
# rapCavOverlapBM = 1 - rapCavOverlapBM[0]

rapCavTimeGapBM = beastModeOverlap.loc[beastModeOverlap['Days_On_RapCaviar'].notnull()]
rapCavTimeGapBM = rapCavTimeGapBM['Days_On_RapCaviar'].mean()

# %% [markdown]
# # Beast Mode Overlap Table

# %%
beastModeOverlapDF = rapStatsAgg.iloc[:,0:2].sort_values('Playlist_Followers', ascending=False)
beastModeOverlapDF['Overlap'] =  (rapCavOverlapBM, 1, getTurntOverlapBM, powerWorkoutOverlapBM,
                                      hotHitsUkOverlapBM, mostNecessaryOverlapBM, topHitsGermanyOverlapBM, hotRhythmicOverlapBM,
                                      lswOverlapBM, baeOverlapBM, signedXoxoOverlapBM, channelXOverlapBM,
                                      workoutTwerkoutOverlapBM, hotHitsAusOverlapBM, bedroomJamsOverlapBM, mellowBarsOverlapBM,
                                      realestDownSouthOverlapBM, offTheStrengthOverlapBM, grimeShutdownOverlapBM, topHitsNLOverlapBM,
                                      hipHopCentralOverlapBM, singledOutOverlapBM, shishaLoungeOverlapBM, theNewnessOverlapBM, 
                                      lockedInOverlapBM, mindRightOverlapBM, caliFireOverlapBM, rapUKOverlapBM,
                                      hipHopMixtapeOverlapBM, whoWeBeOverlapBM, altHipHopOverlapBM, swagOverlapBM,
                                      cloutCultureOverlapBM, antiPopOverlapBM, spilledInkOverlapBM, rnbRightNowOverlapBM,
                                      stateOfMindOverlapBM, a1HipHopOverlapBM, hotHipHopOverlapBM, hipHopYogaOverlapBM,
                                      beatsRhymesOverlapBM, urbanFlavourOverlapBM, afroBashmentOverlapBM, newMusicNowOverlapBM,
                                      internetPeopleOverlapBM, hipHopMixOverlapBM, hotHitsNZOverlapBM)
beastModeOverlapDF['Timegap'] =  (rapCavTimeGapBM, beastModeTimeGapBM, getTurntTimeGapBM, powerWorkoutTimeGapBM,
                                      hotHitsUkTimeGapBM, mostNecessaryTimeGapBM, topHitsGermanyTimeGapBM, hotRhythmicTimeGapBM,
                                      lswTimeGapBM, baeTimeGapBM, signedXoxoTimeGapBM, channelXTimeGapBM,
                                      workoutTwerkoutTimeGapBM, hotHitsAusTimeGapBM, bedroomJamsTimeGapBM, mellowBarsTimeGapBM,
                                      realestDownSouthTimeGapBM, offTheStrengthTimeGapBM, grimeShutdownTimeGapBM, topHitsNlTimeGapBM,
                                      hipHopCentralTimeGapBM, singledOutTimeGapBM, shishaLoungeTimeGapBM, theNewnessTimeGapBM, 
                                      lockedInTimeGapBM, mindRightTimeGapBM, caliFireTimeGapBM, rapUkTimeGapBM,
                                      hipHopMixtapeTimeGapBM, whoWeBeTimeGapBM, altHipHopTimeGapBM, swagTimeGapBM,
                                      cloutCultureTimeGapBM, antiPopTimeGapBM, spilledInkTimeGapBM, rnbRightNowTimeGapBM,
                                      stateOfMindTimeGapBM, a1HipHopTimeGapBM, hotHipHopTimeGapBM, hipHopYogaTimeGapBM,
                                      beatsRhymesTimeGapBM, urbanFlavourTimeGapBM, afroBashmentTimeGapBM, newMusicNowTimeGapBM,
                                      internetPeopleTimeGapBM, hipHopMixTimeGapBM, hotHitsNZTimeGapBM)

beastModeOverlapDF.reset_index(drop=True)
format_dict_new_BM = {'Playlist Followers': '{:,}', 'Overlap':'{:.2%}', 'Timegap':'{:,.0f}'}
beastModeOverlapDF = beastModeOverlapDF[beastModeOverlapDF.Overlap != 0]
# beastModeOverlapDF = beastModeOverlapDF[beastModeOverlapDF.Overlap != 1]
beastModeOverlapDF.columns = beastModeOverlapDF.columns.str.replace('_', ' ')
beastModeOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new_BM).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('Beast Mode Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_97055fca_6556_11ea_b195_3af9d3abd3acrow0_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_97055fca_6556_11ea_b195_3af9d3abd3acrow1_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_97055fca_6556_11ea_b195_3af9d3abd3acrow2_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_97055fca_6556_11ea_b195_3af9d3abd3acrow3_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_97055fca_6556_11ea_b195_3af9d3abd3acrow4_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_97055fca_6556_11ea_b195_3af9d3abd3acrow5_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_97055fca_6556_11ea_b195_3af9d3abd3acrow6_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
# ...

# %% [markdown]
# # Get Turnt Path

# %%
getTurntOverlap = rap.loc[rap['Get_Turnt']==1]
getTurntOverlap = getTurntOverlap[getTurntOverlap['Days_On_Get_Turnt'].isin([0.0])]

hotHitsNZOverlapGT = getTurntOverlap['Hot_Hits_New_Zealand'].value_counts(normalize=True)
hotHitsNZOverlapGT = 1 - hotHitsNZOverlapGT[0]

hotHitsNZTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hot_Hits_New_Zealand'].notnull()]
hotHitsNZTimeGapGT = hotHitsNZTimeGapGT['Days_On_Hot_Hits_New_Zealand'].mean()

hipHopMixOverlapGT = getTurntOverlap['Hip_Hop_Mix'].value_counts(normalize=True)
hipHopMixOverlapGT = 1 - hipHopMixOverlapGT[0]

hipHopMixTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hip_Hop_Mix'].notnull()]
hipHopMixTimeGapGT = hipHopMixTimeGapGT['Days_On_Hip_Hop_Mix'].mean()

internetPeopleOverlapGT = getTurntOverlap['Internet_People'].value_counts(normalize=True)
internetPeopleOverlapGT = 1 - internetPeopleOverlapGT[0]

internetPeopleTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Internet_People'].notnull()]
internetPeopleTimeGapGT = internetPeopleTimeGapGT['Days_On_Internet_People'].mean()

newMusicNowOverlapGT = getTurntOverlap['New_Music_Now'].value_counts(normalize=True)
newMusicNowOverlapGT = 1 - newMusicNowOverlapGT[0]

newMusicNowTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_New_Music_Now'].notnull()]
newMusicNowTimeGapGT = newMusicNowTimeGapGT['Days_On_New_Music_Now'].mean()

afroBashmentOverlapGT = getTurntOverlap['Afro_Bashment'].value_counts(normalize=True)
afroBashmentOverlapGT = 1 - afroBashmentOverlapGT[0]

afroBashmentTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Afro_Bashment'].notnull()]
afroBashmentTimeGapGT = afroBashmentTimeGapGT['Days_On_Afro_Bashment'].mean()

urbanFlavourOverlapGT = getTurntOverlap['Urban_Flavour'].value_counts(normalize=True)
urbanFlavourOverlapGT = 1 - urbanFlavourOverlapGT[0]

urbanFlavourTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Urban_Flavour'].notnull()]
urbanFlavourTimeGapGT = urbanFlavourTimeGapGT['Days_On_Urban_Flavour'].mean()

beatsRhymesOverlapGT = getTurntOverlap['Beats_&_Rhymes'].value_counts(normalize=True)
beatsRhymesOverlapGT = 1 - beatsRhymesOverlapGT[0]

beatsRhymesTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Beats_&_Rhymes'].notnull()]
beatsRhymesTimeGapGT = beatsRhymesTimeGapGT['Days_On_Beats_&_Rhymes'].mean()

hipHopYogaOverlapGT = getTurntOverlap['Hip-Hop_Yoga'].value_counts(normalize=True)
hipHopYogaOverlapGT = 1 - hipHopYogaOverlapGT[0]

hipHopYogaTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hip-Hop_Yoga'].notnull()]
hipHopYogaTimeGapGT = hipHopYogaTimeGapGT['Days_On_Hip-Hop_Yoga'].mean()

hotHipHopOverlapGT = getTurntOverlap['Hot_Hip_Hop'].value_counts(normalize=True)
hotHipHopOverlapGT = 1 - hotHipHopOverlapGT[0]

hotHipHopTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hot_Hip_Hop'].notnull()]
hotHipHopTimeGapGT = hotHipHopTimeGapGT['Days_On_Hot_Hip_Hop'].mean()

a1HipHopOverlapGT = getTurntOverlap['A1_Hip-Hop'].value_counts(normalize=True)
a1HipHopOverlapGT = 1 - a1HipHopOverlapGT[0]

a1HipHopTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_A1_Hip-Hop'].notnull()]
a1HipHopTimeGapGT = a1HipHopTimeGapGT['Days_On_A1_Hip-Hop'].mean()

stateOfMindOverlapGT = getTurntOverlap['State_of_Mind'].value_counts(normalize=True)
stateOfMindOverlapGT = 1 - stateOfMindOverlapGT[0]

stateOfMindTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_State_of_Mind'].notnull()]
stateOfMindTimeGapGT = stateOfMindTimeGapGT['Days_On_State_of_Mind'].mean()

rnbRightNowOverlapGT = getTurntOverlap['R&B_Right_Now'].value_counts(normalize=True)
rnbRightNowOverlapGT = 1 - rnbRightNowOverlapGT[0]

rnbRightNowTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_R&B_Right_Now'].notnull()]
rnbRightNowTimeGapGT = rnbRightNowTimeGapGT['Days_On_R&B_Right_Now'].mean()

spilledInkOverlapGT = getTurntOverlap['Spilled_Ink'].value_counts(normalize=True)
spilledInkOverlapGT = 1 - spilledInkOverlapGT[0]

spilledInkTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Spilled_Ink'].notnull()]
spilledInkTimeGapGT = spilledInkTimeGapGT['Days_On_Spilled_Ink'].mean()

antiPopOverlapGT = getTurntOverlap['Anti_Pop'].value_counts(normalize=True)
antiPopOverlapGT = 1 - antiPopOverlapGT[0]

antiPopTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Anti_Pop'].notnull()]
antiPopTimeGapGT = antiPopTimeGapGT['Days_On_Anti_Pop'].mean()

cloutCultureOverlapGT = getTurntOverlap['Clout_Culture'].value_counts(normalize=True)
cloutCultureOverlapGT = 1 - cloutCultureOverlapGT[0]

cloutCultureTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Clout_Culture'].notnull()]
cloutCultureTimeGapGT = cloutCultureTimeGapGT['Days_On_Clout_Culture'].mean()

swagOverlapGT = getTurntOverlap['Swag!'].value_counts(normalize=True)
swagOverlapGT = 1 - swagOverlapGT[0]

swagTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Swag!'].notnull()]
swagTimeGapGT = swagTimeGapGT['Days_On_Swag!'].mean()

altHipHopOverlapGT = getTurntOverlap['Alternative_Hip_Hop'].value_counts(normalize=True)
altHipHopOverlapGT = 1 - altHipHopOverlapGT[0]

altHipHopTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Alternative_Hip_Hop'].notnull()]
altHipHopTimeGapGT = altHipHopTimeGapGT['Days_On_Alternative_Hip_Hop'].mean()

whoWeBeOverlapGT = getTurntOverlap['Who_We_Be'].value_counts(normalize=True)
whoWeBeOverlapGT = 1 - whoWeBeOverlapGT[0]

whoWeBeTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Who_We_Be'].notnull()]
whoWeBeTimeGapGT = whoWeBeTimeGapGT['Days_On_Who_We_Be'].mean()

hipHopMixtapeOverlapGT = getTurntOverlap['Hip-Hop_Mixtape'].value_counts(normalize=True)
hipHopMixtapeOverlapGT = 1 - hipHopMixtapeOverlapGT[0]

hipHopMixtapeTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hip-Hop_Mixtape'].notnull()]
hipHopMixtapeTimeGapGT = hipHopMixtapeTimeGapGT['Days_On_Hip-Hop_Mixtape'].mean()

rapUKOverlapGT = getTurntOverlap['Rap_UK'].value_counts(normalize=True)
rapUKOverlapGT = 1 - rapUKOverlapGT[0]

rapUkTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Rap_UK'].notnull()]
rapUkTimeGapGT = rapUkTimeGapGT['Days_On_Rap_UK'].mean()

caliFireOverlapGT = getTurntOverlap['Cali_Fire'].value_counts(normalize=True)
caliFireOverlapGT = 1 - caliFireOverlapGT[0]

caliFireTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Cali_Fire'].notnull()]
caliFireTimeGapGT = caliFireTimeGapGT['Days_On_Cali_Fire'].mean()

mindRightOverlapGT = getTurntOverlap['Mind_Right'].value_counts(normalize=True)
mindRightOverlapGT = 1 - mindRightOverlapGT[0]

mindRightTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Mind_Right'].notnull()]
mindRightTimeGapGT = mindRightTimeGapGT['Days_On_Mind_Right'].mean()

lockedInOverlapGT = getTurntOverlap['Locked_In'].value_counts(normalize=True)
lockedInOverlapGT = 1 - lockedInOverlapGT[0]

lockedInTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Locked_In'].notnull()]
lockedInTimeGapGT = lockedInTimeGapGT['Days_On_Locked_In'].mean()

theNewnessOverlapGT = getTurntOverlap['The_Newness'].value_counts(normalize=True)
theNewnessOverlapGT = 1 - theNewnessOverlapGT[0]

theNewnessTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_The_Newness'].notnull()]
theNewnessTimeGapGT = theNewnessTimeGapGT['Days_On_The_Newness'].mean()

shishaLoungeOverlapGT = getTurntOverlap['Shisha_Lounge'].value_counts(normalize=True)
shishaLoungeOverlapGT = 1 - shishaLoungeOverlapGT[0]

shishaLoungeTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Shisha_Lounge'].notnull()]
shishaLoungeTimeGapGT = shishaLoungeTimeGapGT['Days_On_Shisha_Lounge'].mean()

singledOutOverlapGT = getTurntOverlap['Singled_Out'].value_counts(normalize=True)
singledOutOverlapGT = 1 - singledOutOverlapGT[0]

singledOutTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Singled_Out'].notnull()]
singledOutTimeGapGT = singledOutTimeGapGT['Days_On_Singled_Out'].mean()

hipHopCentralOverlapGT = getTurntOverlap['Hip-Hop_Central'].value_counts(normalize=True)
hipHopCentralOverlapGT = 1 - hipHopCentralOverlapGT[0]

hipHopCentralTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hip-Hop_Central'].notnull()]
hipHopCentralTimeGapGT = hipHopCentralTimeGapGT['Days_On_Hip-Hop_Central'].mean()

topHitsNLOverlapGT = getTurntOverlap['Top_Hits_NL'].value_counts(normalize=True)
topHitsNLOverlapGT = 1 - topHitsNLOverlapGT[0]

topHitsNlTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Top_Hits_NL'].notnull()]
topHitsNlTimeGapGT = topHitsNlTimeGapGT['Days_On_Top_Hits_NL'].mean()

grimeShutdownOverlapGT = getTurntOverlap['Grime_Shutdown'].value_counts(normalize=True)
grimeShutdownOverlapGT = 1 - grimeShutdownOverlapGT[0]

grimeShutdownTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Grime_Shutdown'].notnull()]
grimeShutdownTimeGapGT = grimeShutdownTimeGapGT['Days_On_Grime_Shutdown'].mean()

offTheStrengthOverlapGT = getTurntOverlap['Off_The_Strength'].value_counts(normalize=True)
offTheStrengthOverlapGT = 1 - offTheStrengthOverlapGT[0]

offTheStrengthTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Off_The_Strength'].notnull()]
offTheStrengthTimeGapGT = offTheStrengthTimeGapGT['Days_On_Off_The_Strength'].mean()

realestDownSouthOverlapGT = getTurntOverlap['The_Realest_Down_South'].value_counts(normalize=True)
realestDownSouthOverlapGT = 1 - realestDownSouthOverlapGT[0]

realestDownSouthTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_The_Realest_Down_South'].notnull()]
realestDownSouthTimeGapGT = realestDownSouthTimeGapGT['Days_On_The_Realest_Down_South'].mean()

mellowBarsOverlapGT = getTurntOverlap['Mellow_Bars'].value_counts(normalize=True)
mellowBarsOverlapGT = 1 - mellowBarsOverlapGT[0]

mellowBarsTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Mellow_Bars'].notnull()]
mellowBarsTimeGapGT = mellowBarsTimeGapGT['Days_On_Mellow_Bars'].mean()

bedroomJamsOverlapGT = getTurntOverlap['Bedroom_Jams'].value_counts(normalize=True)
bedroomJamsOverlapGT = 1 - bedroomJamsOverlapGT[0]

bedroomJamsTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Bedroom_Jams'].notnull()]
bedroomJamsTimeGapGT = bedroomJamsTimeGapGT['Days_On_Bedroom_Jams'].mean()

hotHitsAusOverlapGT = getTurntOverlap['Hot_Hits_Australia'].value_counts(normalize=True)
hotHitsAusOverlapGT = 1 - hotHitsAusOverlapGT[0]

hotHitsAusTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hot_Hits_Australia'].notnull()]
hotHitsAusTimeGapGT = hotHitsAusTimeGapGT['Days_On_Hot_Hits_Australia'].mean()

workoutTwerkoutOverlapGT = getTurntOverlap['Workout_Twerkout'].value_counts(normalize=True)
workoutTwerkoutOverlapGT = 1 - workoutTwerkoutOverlapGT[0]

workoutTwerkoutTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Workout_Twerkout'].notnull()]
workoutTwerkoutTimeGapGT = workoutTwerkoutTimeGapGT['Days_On_Workout_Twerkout'].mean()

channelXOverlapGT = getTurntOverlap['Channel_X'].value_counts(normalize=True)
channelXOverlapGT = 1 - channelXOverlapGT[0]

channelXTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Channel_X'].notnull()]
channelXTimeGapGT = channelXTimeGapGT['Days_On_Channel_X'].mean()

signedXoxoOverlapGT = getTurntOverlap['Signed_XOXO'].value_counts(normalize=True)
signedXoxoOverlapGT = 1 - signedXoxoOverlapGT[0]

signedXoxoTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Signed_XOXO'].notnull()]
signedXoxoTimeGapGT = signedXoxoTimeGapGT['Days_On_Signed_XOXO'].mean()

baeOverlapGT = getTurntOverlap['BAE'].value_counts(normalize=True)
baeOverlapGT = 1 - baeOverlapGT[0]

baeTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_BAE'].notnull()]
baeTimeGapGT = baeTimeGapGT['Days_On_BAE'].mean()

lswOverlapGT = getTurntOverlap['Love,_Sex,_&_Water'].value_counts(normalize=True)
lswOverlapGT = 1 - lswOverlapGT[0]

lswTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Love,_Sex,_&_Water'].notnull()]
lswTimeGapGT = lswTimeGapGT['Days_On_Love,_Sex,_&_Water'].mean()

hotRhythmicOverlapGT = getTurntOverlap['Hot_Rhythmic'].value_counts(normalize=True)
hotRhythmicOverlapGT = 1 - hotRhythmicOverlapGT[0]

hotRhythmicTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hot_Rhythmic'].notnull()]
hotRhythmicTimeGapGT = hotRhythmicTimeGapGT['Days_On_Hot_Rhythmic'].mean()

topHitsGermanyOverlapGT = getTurntOverlap['Top_Hits_Deutschland'].value_counts(normalize=True)
topHitsGermanyOverlapGT = 1 - topHitsGermanyOverlapGT[0]

topHitsGermanyTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Top_Hits_Deutschland'].notnull()]
topHitsGermanyTimeGapGT = topHitsGermanyTimeGapGT['Days_On_Top_Hits_Deutschland'].mean()

hotHitsUkOverlapGT = getTurntOverlap['Hot_Hits_UK'].value_counts(normalize=True)
hotHitsUkOverlapGT = 1 - hotHitsUkOverlapGT[0]

hotHitsUkTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Hot_Hits_UK'].notnull()]
hotHitsUkTimeGapGT = hotHitsUkTimeGapGT['Days_On_Hot_Hits_UK'].mean()

mostNecessaryOverlapGT = getTurntOverlap['Most_Necessary'].value_counts(normalize=True)
mostNecessaryOverlapGT = 1 - mostNecessaryOverlapGT[0]

mostNecessaryTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Most_Necessary'].notnull()]
mostNecessaryTimeGapGT = mostNecessaryTimeGapGT['Days_On_Most_Necessary'].mean()

beastModeOverlapGT = getTurntOverlap['Beast_Mode'].value_counts(normalize=True)
beastModeOverlapGT = 1 - beastModeOverlapGT[0]

beastModeTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Beast_Mode'].notnull()]
beastModeTimeGapGT = beastModeTimeGapGT['Days_On_Beast_Mode'].mean()

getTurntTimeGapGT = 0

powerWorkoutOverlapGT = getTurntOverlap['Power_Workout'].value_counts(normalize=True)
powerWorkoutOverlapGT = 1 - powerWorkoutOverlapGT[0]

powerWorkoutTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_Power_Workout'].notnull()]
powerWorkoutTimeGapGT = powerWorkoutTimeGapGT['Days_On_Power_Workout'].mean()

rapCavOverlapGT = getTurntOverlap['RapCaviar'].value_counts(normalize=True)
rapCavOverlapGT = 1 - rapCavOverlapGT[0]

rapCavTimeGapGT = getTurntOverlap.loc[getTurntOverlap['Days_On_RapCaviar'].notnull()]
rapCavTimeGapGT = rapCavTimeGapGT['Days_On_RapCaviar'].mean()

# %% [markdown]
# # Get Turnt Overlap Table

# %%
getTurntOverlapDF = rapStatsAgg.iloc[:,0:2].sort_values('Playlist_Followers', ascending=False)
getTurntOverlapDF['Overlap'] =  (rapCavOverlapGT, beastModeOverlapGT, 1, powerWorkoutOverlapGT,
                                      hotHitsUkOverlapGT, mostNecessaryOverlapGT, topHitsGermanyOverlapGT, hotRhythmicOverlapGT,
                                      lswOverlapGT, baeOverlapGT, signedXoxoOverlapGT, channelXOverlapGT,
                                      workoutTwerkoutOverlapGT, hotHitsAusOverlapGT, bedroomJamsOverlapGT, mellowBarsOverlapGT,
                                      realestDownSouthOverlapGT, offTheStrengthOverlapGT, grimeShutdownOverlapGT, topHitsNLOverlapGT,
                                      hipHopCentralOverlapGT, singledOutOverlapGT, shishaLoungeOverlapGT, theNewnessOverlapGT, 
                                      lockedInOverlapGT, mindRightOverlapGT, caliFireOverlapGT, rapUKOverlapGT,
                                      hipHopMixtapeOverlapGT, whoWeBeOverlapGT, altHipHopOverlapGT, swagOverlapGT,
                                      cloutCultureOverlapGT, antiPopOverlapGT, spilledInkOverlapGT, rnbRightNowOverlapGT,
                                      stateOfMindOverlapGT, a1HipHopOverlapGT, hotHipHopOverlapGT, hipHopYogaOverlapGT,
                                      beatsRhymesOverlapGT, urbanFlavourOverlapGT, afroBashmentOverlapGT, newMusicNowOverlapGT,
                                      internetPeopleOverlapGT, hipHopMixOverlapGT, hotHitsNZOverlapGT)
getTurntOverlapDF['Timegap'] =  (rapCavTimeGapGT, beastModeTimeGapGT, getTurntTimeGapGT, powerWorkoutTimeGapGT,
                                      hotHitsUkTimeGapGT, mostNecessaryTimeGapGT, topHitsGermanyTimeGapGT, hotRhythmicTimeGapGT,
                                      lswTimeGapGT, baeTimeGapGT, signedXoxoTimeGapGT, channelXTimeGapGT,
                                      workoutTwerkoutTimeGapGT, hotHitsAusTimeGapGT, bedroomJamsTimeGapGT, mellowBarsTimeGapGT,
                                      realestDownSouthTimeGapGT, offTheStrengthTimeGapGT, grimeShutdownTimeGapGT, topHitsNlTimeGapGT,
                                      hipHopCentralTimeGapGT, singledOutTimeGapGT, shishaLoungeTimeGapGT, theNewnessTimeGapGT, 
                                      lockedInTimeGapGT, mindRightTimeGapGT, caliFireTimeGapGT, rapUkTimeGapGT,
                                      hipHopMixtapeTimeGapGT, whoWeBeTimeGapGT, altHipHopTimeGapGT, swagTimeGapGT,
                                      cloutCultureTimeGapGT, antiPopTimeGapGT, spilledInkTimeGapGT, rnbRightNowTimeGapGT,
                                      stateOfMindTimeGapGT, a1HipHopTimeGapGT, hotHipHopTimeGapGT, hipHopYogaTimeGapGT,
                                      beatsRhymesTimeGapGT, urbanFlavourTimeGapGT, afroBashmentTimeGapGT, newMusicNowTimeGapGT,
                                      internetPeopleTimeGapGT, hipHopMixTimeGapGT, hotHitsNZTimeGapGT)

getTurntOverlapDF.reset_index(drop=True)
format_dict_new_GT = {'Playlist Followers': '{:,}', 'Overlap':'{:.2%}', 'Timegap':'{:,.0f}'}
getTurntOverlapDF = getTurntOverlapDF[getTurntOverlapDF.Overlap != 0]
getTurntOverlapDF = getTurntOverlapDF[getTurntOverlapDF.Overlap != 1]
getTurntOverlapDF.columns = getTurntOverlapDF.columns.str.replace('_', ' ')
getTurntOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new_GT).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('Get Turnt Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_9a6f259c_6556_11ea_b195_3af9d3abd3acrow0_col2 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_9a6f259c_6556_11ea_b195_3af9d3abd3acrow1_col2 {
#             background-color:  #ffb600;
#             color:  #000000;
#         }    #T_9a6f259c_6556_11ea_b195_3af9d3abd3acrow2_col2 {
#             background-color:  #ffb600;
#             color:  #000000;
#         }    #T_9a6f259c_6556_11ea_b195_3af9d3abd3acrow3_col2 {
#             background-color:  #ffc706;
#             color:  #000000;
#         }    #T_9a6f259c_6556_11ea_b195_3af9d3abd3acrow4_col2 {
#             background-color:  #f0f550;
#             color:  #000000;
#         }    #T_9a6f259c_6556_11ea_b195_3af9d3abd3acrow5_col2 {
#             background-color:  #f0f550;
#             color:  #000000;
#         }    #T_9a6f259c_6556_11ea_b195_3af9d3abd3acrow6_col2 {
#             background-color:  #f0f550;
#             color:  #000000;
# ...

# %% [markdown]
# # Power Workout Path

# %%
powerWorkoutOverlap = rap.loc[rap['Power_Workout']==1]
powerWorkoutOverlap = powerWorkoutOverlap[powerWorkoutOverlap['Days_On_Power_Workout'].isin([0.0])]

hotHitsNZOverlapPW = powerWorkoutOverlap['Hot_Hits_New_Zealand'].value_counts(normalize=True)
hotHitsNZOverlapPW = 1 - hotHitsNZOverlapPW[0]

hotHitsNZTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hot_Hits_New_Zealand'].notnull()]
hotHitsNZTimeGapPW = hotHitsNZTimeGapPW['Days_On_Hot_Hits_New_Zealand'].mean()

hipHopMixOverlapPW = powerWorkoutOverlap['Hip_Hop_Mix'].value_counts(normalize=True)
hipHopMixOverlapPW = 1 - hipHopMixOverlapPW[0]

hipHopMixTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hip_Hop_Mix'].notnull()]
hipHopMixTimeGapPW = hipHopMixTimeGapPW['Days_On_Hip_Hop_Mix'].mean()

internetPeopleOverlapPW = powerWorkoutOverlap['Internet_People'].value_counts(normalize=True)
internetPeopleOverlapPW = 1 - internetPeopleOverlapPW[0]

internetPeopleTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Internet_People'].notnull()]
internetPeopleTimeGapPW = internetPeopleTimeGapPW['Days_On_Internet_People'].mean()

newMusicNowOverlapPW = powerWorkoutOverlap['New_Music_Now'].value_counts(normalize=True)
newMusicNowOverlapPW = 1 - newMusicNowOverlapPW[0]

newMusicNowTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_New_Music_Now'].notnull()]
newMusicNowTimeGapPW = newMusicNowTimeGapPW['Days_On_New_Music_Now'].mean()

afroBashmentOverlapPW = powerWorkoutOverlap['Afro_Bashment'].value_counts(normalize=True)
afroBashmentOverlapPW = afroBashmentOverlapPW[1]
# afroBashmentOverlapPW = 1 - afroBashmentOverlapPW[0]

afroBashmentTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Afro_Bashment'].notnull()]
afroBashmentTimeGapPW = afroBashmentTimeGapPW['Days_On_Afro_Bashment'].mean()

urbanFlavourOverlapPW = powerWorkoutOverlap['Urban_Flavour'].value_counts(normalize=True)
urbanFlavourOverlapPW = 1 - urbanFlavourOverlapPW[0]

urbanFlavourTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Urban_Flavour'].notnull()]
urbanFlavourTimeGapPW = urbanFlavourTimeGapPW['Days_On_Urban_Flavour'].mean()

beatsRhymesOverlapPW = powerWorkoutOverlap['Beats_&_Rhymes'].value_counts(normalize=True)
beatsRhymesOverlapPW = 1 - beatsRhymesOverlapPW[0]

beatsRhymesTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Beats_&_Rhymes'].notnull()]
beatsRhymesTimeGapPW = beatsRhymesTimeGapPW['Days_On_Beats_&_Rhymes'].mean()

hipHopYogaOverlapPW = powerWorkoutOverlap['Hip-Hop_Yoga'].value_counts(normalize=True)
hipHopYogaOverlapPW = 1 - hipHopYogaOverlapPW[0]

hipHopYogaTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hip-Hop_Yoga'].notnull()]
hipHopYogaTimeGapPW = hipHopYogaTimeGapPW['Days_On_Hip-Hop_Yoga'].mean()

hotHipHopOverlapPW = powerWorkoutOverlap['Hot_Hip_Hop'].value_counts(normalize=True)
hotHipHopOverlapPW = 1 - hotHipHopOverlapPW[0]

hotHipHopTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hot_Hip_Hop'].notnull()]
hotHipHopTimeGapPW = hotHipHopTimeGapPW['Days_On_Hot_Hip_Hop'].mean()

a1HipHopOverlapPW = powerWorkoutOverlap['A1_Hip-Hop'].value_counts(normalize=True)
a1HipHopOverlapPW = 1 - a1HipHopOverlapPW[0]

a1HipHopTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_A1_Hip-Hop'].notnull()]
a1HipHopTimeGapPW = a1HipHopTimeGapPW['Days_On_A1_Hip-Hop'].mean()

stateOfMindOverlapPW = powerWorkoutOverlap['State_of_Mind'].value_counts(normalize=True)
stateOfMindOverlapPW = 1 - stateOfMindOverlapPW[0]

stateOfMindTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_State_of_Mind'].notnull()]
stateOfMindTimeGapPW = stateOfMindTimeGapPW['Days_On_State_of_Mind'].mean()

rnbRightNowOverlapPW = powerWorkoutOverlap['R&B_Right_Now'].value_counts(normalize=True)
rnbRightNowOverlapPW = 1 - rnbRightNowOverlapPW[0]

rnbRightNowTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_R&B_Right_Now'].notnull()]
rnbRightNowTimeGapPW = rnbRightNowTimeGapPW['Days_On_R&B_Right_Now'].mean()

spilledInkOverlapPW = powerWorkoutOverlap['Spilled_Ink'].value_counts(normalize=True)
spilledInkOverlapPW = 1 - spilledInkOverlapPW[0]

spilledInkTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Spilled_Ink'].notnull()]
spilledInkTimeGapPW = spilledInkTimeGapPW['Days_On_Spilled_Ink'].mean()

antiPopOverlapPW = powerWorkoutOverlap['Anti_Pop'].value_counts(normalize=True)
antiPopOverlapPW = 1 - antiPopOverlapPW[0]

antiPopTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Anti_Pop'].notnull()]
antiPopTimeGapPW = antiPopTimeGapPW['Days_On_Anti_Pop'].mean()

cloutCultureOverlapPW = powerWorkoutOverlap['Clout_Culture'].value_counts(normalize=True)
cloutCultureOverlapPW = 1 - cloutCultureOverlapPW[0]

cloutCultureTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Clout_Culture'].notnull()]
cloutCultureTimeGapPW = cloutCultureTimeGapPW['Days_On_Clout_Culture'].mean()

swagOverlapPW = powerWorkoutOverlap['Swag!'].value_counts(normalize=True)
swagOverlapPW = 1 - swagOverlapPW[0]

swagTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Swag!'].notnull()]
swagTimeGapPW = swagTimeGapPW['Days_On_Swag!'].mean()

altHipHopOverlapPW = powerWorkoutOverlap['Alternative_Hip_Hop'].value_counts(normalize=True)
altHipHopOverlapPW = 1 - altHipHopOverlapPW[0]

altHipHopTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Alternative_Hip_Hop'].notnull()]
altHipHopTimeGapPW = altHipHopTimeGapPW['Days_On_Alternative_Hip_Hop'].mean()

whoWeBeOverlapPW = powerWorkoutOverlap['Who_We_Be'].value_counts(normalize=True)
whoWeBeOverlapPW = whoWeBeOverlapPW[1]
# whoWeBeOverlapPW = 1 - whoWeBeOverlapPW[0]

whoWeBeTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Who_We_Be'].notnull()]
whoWeBeTimeGapPW = whoWeBeTimeGapPW['Days_On_Who_We_Be'].mean()

hipHopMixtapeOverlapPW = powerWorkoutOverlap['Hip-Hop_Mixtape'].value_counts(normalize=True)
hipHopMixtapeOverlapPW = 1 - hipHopMixtapeOverlapPW[0]

hipHopMixtapeTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hip-Hop_Mixtape'].notnull()]
hipHopMixtapeTimeGapPW = hipHopMixtapeTimeGapPW['Days_On_Hip-Hop_Mixtape'].mean()

rapUKOverlapPW = powerWorkoutOverlap['Rap_UK'].value_counts(normalize=True)
rapUKOverlapPW = rapUKOverlapPW[1]
# rapUKOverlapPW = 1 - rapUKOverlapPW[0]

rapUkTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Rap_UK'].notnull()]
rapUkTimeGapPW = rapUkTimeGapPW['Days_On_Rap_UK'].mean()

caliFireOverlapPW = powerWorkoutOverlap['Cali_Fire'].value_counts(normalize=True)
caliFireOverlapPW = 1 - caliFireOverlapPW[0]

caliFireTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Cali_Fire'].notnull()]
caliFireTimeGapPW = caliFireTimeGapPW['Days_On_Cali_Fire'].mean()

mindRightOverlapPW = powerWorkoutOverlap['Mind_Right'].value_counts(normalize=True)
mindRightOverlapPW = 1 - mindRightOverlapPW[0]

mindRightTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Mind_Right'].notnull()]
mindRightTimeGapPW = mindRightTimeGapPW['Days_On_Mind_Right'].mean()

lockedInOverlapPW = powerWorkoutOverlap['Locked_In'].value_counts(normalize=True)
lockedInOverlapPW = 1 - lockedInOverlapPW[0]

lockedInTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Locked_In'].notnull()]
lockedInTimeGapPW = lockedInTimeGapPW['Days_On_Locked_In'].mean()

theNewnessOverlapPW = powerWorkoutOverlap['The_Newness'].value_counts(normalize=True)
theNewnessOverlapPW = 1 - theNewnessOverlapPW[0]

theNewnessTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_The_Newness'].notnull()]
theNewnessTimeGapPW = theNewnessTimeGapPW['Days_On_The_Newness'].mean()

shishaLoungeOverlapPW = powerWorkoutOverlap['Shisha_Lounge'].value_counts(normalize=True)
shishaLoungeOverlapPW = 1 - shishaLoungeOverlapPW[0]

shishaLoungeTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Shisha_Lounge'].notnull()]
shishaLoungeTimeGapPW = shishaLoungeTimeGapPW['Days_On_Shisha_Lounge'].mean()

singledOutOverlapPW = powerWorkoutOverlap['Singled_Out'].value_counts(normalize=True)
singledOutOverlapPW = 1 - singledOutOverlapPW[0]

singledOutTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Singled_Out'].notnull()]
singledOutTimeGapPW = singledOutTimeGapPW['Days_On_Singled_Out'].mean()

hipHopCentralOverlapPW = powerWorkoutOverlap['Hip-Hop_Central'].value_counts(normalize=True)
hipHopCentralOverlapPW = 1 - hipHopCentralOverlapPW[0]

hipHopCentralTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hip-Hop_Central'].notnull()]
hipHopCentralTimeGapPW = hipHopCentralTimeGapPW['Days_On_Hip-Hop_Central'].mean()

topHitsNLOverlapPW = powerWorkoutOverlap['Top_Hits_NL'].value_counts(normalize=True)
topHitsNLOverlapPW = 1 - topHitsNLOverlapPW[0]

topHitsNlTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Top_Hits_NL'].notnull()]
topHitsNlTimeGapPW = topHitsNlTimeGapPW['Days_On_Top_Hits_NL'].mean()

grimeShutdownOverlapPW = powerWorkoutOverlap['Grime_Shutdown'].value_counts(normalize=True)
grimeShutdownOverlapPW = 1 - grimeShutdownOverlapPW[0]

grimeShutdownTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Grime_Shutdown'].notnull()]
grimeShutdownTimeGapPW = grimeShutdownTimeGapPW['Days_On_Grime_Shutdown'].mean()

offTheStrengthOverlapPW = powerWorkoutOverlap['Off_The_Strength'].value_counts(normalize=True)
offTheStrengthOverlapPW = 1 - offTheStrengthOverlapPW[0]

offTheStrengthTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Off_The_Strength'].notnull()]
offTheStrengthTimeGapPW = offTheStrengthTimeGapPW['Days_On_Off_The_Strength'].mean()

realestDownSouthOverlapPW = powerWorkoutOverlap['The_Realest_Down_South'].value_counts(normalize=True)
realestDownSouthOverlapPW = 1 - realestDownSouthOverlapPW[0]

realestDownSouthTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_The_Realest_Down_South'].notnull()]
realestDownSouthTimeGapPW = realestDownSouthTimeGapPW['Days_On_The_Realest_Down_South'].mean()

mellowBarsOverlapPW = powerWorkoutOverlap['Mellow_Bars'].value_counts(normalize=True)
mellowBarsOverlapPW = 1 - mellowBarsOverlapPW[0]

mellowBarsTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Mellow_Bars'].notnull()]
mellowBarsTimeGapPW = mellowBarsTimeGapPW['Days_On_Mellow_Bars'].mean()

bedroomJamsOverlapPW = powerWorkoutOverlap['Bedroom_Jams'].value_counts(normalize=True)
bedroomJamsOverlapPW = 1 - bedroomJamsOverlapPW[0]

bedroomJamsTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Bedroom_Jams'].notnull()]
bedroomJamsTimeGapPW = bedroomJamsTimeGapPW['Days_On_Bedroom_Jams'].mean()

hotHitsAusOverlapPW = powerWorkoutOverlap['Hot_Hits_Australia'].value_counts(normalize=True)
hotHitsAusOverlapPW = 1 - hotHitsAusOverlapPW[0]

hotHitsAusTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hot_Hits_Australia'].notnull()]
hotHitsAusTimeGapPW = hotHitsAusTimeGapPW['Days_On_Hot_Hits_Australia'].mean()

workoutTwerkoutOverlapPW = powerWorkoutOverlap['Workout_Twerkout'].value_counts(normalize=True)
workoutTwerkoutOverlapPW = 1 - workoutTwerkoutOverlapPW[0]

workoutTwerkoutTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Workout_Twerkout'].notnull()]
workoutTwerkoutTimeGapPW = workoutTwerkoutTimeGapPW['Days_On_Workout_Twerkout'].mean()

channelXOverlapPW = powerWorkoutOverlap['Channel_X'].value_counts(normalize=True)
channelXOverlapPW = 1 - channelXOverlapPW[0]

channelXTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Channel_X'].notnull()]
channelXTimeGapPW = channelXTimeGapPW['Days_On_Channel_X'].mean()

signedXoxoOverlapPW = powerWorkoutOverlap['Signed_XOXO'].value_counts(normalize=True)
signedXoxoOverlapPW = 1 - signedXoxoOverlapPW[0]

signedXoxoTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Signed_XOXO'].notnull()]
signedXoxoTimeGapPW = signedXoxoTimeGapPW['Days_On_Signed_XOXO'].mean()

baeOverlapPW = powerWorkoutOverlap['BAE'].value_counts(normalize=True)
baeOverlapPW = 1 - baeOverlapPW[0]

baeTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_BAE'].notnull()]
baeTimeGapPW = baeTimeGapPW['Days_On_BAE'].mean()

lswOverlapPW = powerWorkoutOverlap['Love,_Sex,_&_Water'].value_counts(normalize=True)
lswOverlapPW = 1 - lswOverlapPW[0]

lswTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Love,_Sex,_&_Water'].notnull()]
lswTimeGapPW = lswTimeGapPW['Days_On_Love,_Sex,_&_Water'].mean()

hotRhythmicOverlapPW = powerWorkoutOverlap['Hot_Rhythmic'].value_counts(normalize=True)
hotRhythmicOverlapPW = 1 - hotRhythmicOverlapPW[0]

hotRhythmicTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hot_Rhythmic'].notnull()]
hotRhythmicTimeGapPW = hotRhythmicTimeGapPW['Days_On_Hot_Rhythmic'].mean()

topHitsGermanyOverlapPW = powerWorkoutOverlap['Top_Hits_Deutschland'].value_counts(normalize=True)
topHitsGermanyOverlapPW = 1 - topHitsGermanyOverlapPW[0]

topHitsGermanyTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Top_Hits_Deutschland'].notnull()]
topHitsGermanyTimeGapPW = topHitsGermanyTimeGapPW['Days_On_Top_Hits_Deutschland'].mean()

hotHitsUkOverlapPW = powerWorkoutOverlap['Hot_Hits_UK'].value_counts(normalize=True)
hotHitsUkOverlapPW = hotHitsUkOverlapPW[1]
# hotHitsUkOverlapPW = 1 - hotHitsUkOverlapPW[0]

hotHitsUkTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Hot_Hits_UK'].notnull()]
hotHitsUkTimeGapPW = hotHitsUkTimeGapPW['Days_On_Hot_Hits_UK'].mean()

mostNecessaryOverlapPW = powerWorkoutOverlap['Most_Necessary'].value_counts(normalize=True)
mostNecessaryOverlapPW = 1 - mostNecessaryOverlapPW[0]

mostNecessaryTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Most_Necessary'].notnull()]
mostNecessaryTimeGapPW = mostNecessaryTimeGapPW['Days_On_Most_Necessary'].mean()

beastModeOverlapPW = powerWorkoutOverlap['Beast_Mode'].value_counts(normalize=True)
beastModeOverlapPW = 1 - beastModeOverlapPW[0]

beastModeTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Beast_Mode'].notnull()]
beastModeTimeGapPW = beastModeTimeGapPW['Days_On_Beast_Mode'].mean()

getTurntOverlapPW = powerWorkoutOverlap['Get_Turnt'].value_counts(normalize=True)
getTurntOverlapPW = 1 - getTurntOverlapPW[0]

getTurntTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_Get_Turnt'].notnull()]
getTurntTimeGapPW = getTurntTimeGapPW['Days_On_Get_Turnt'].mean()

powerWorkoutTimeGapPW = 0

rapCavOverlapPW = powerWorkoutOverlap['RapCaviar'].value_counts(normalize=True)
rapCavOverlapPW = 1 - rapCavOverlapPW[0]

rapCavTimeGapPW = powerWorkoutOverlap.loc[powerWorkoutOverlap['Days_On_RapCaviar'].notnull()]
rapCavTimeGapPW = rapCavTimeGapPW['Days_On_RapCaviar'].mean()

# %% [markdown]
# # Power Workout Overlap Table

# %%
powerWorkoutOverlapDF = rapStatsAgg.iloc[:,0:2].sort_values('Playlist_Followers', ascending=False)
powerWorkoutOverlapDF['Overlap'] =  (rapCavOverlapPW, beastModeOverlapPW, getTurntOverlapPW, 1,
                                      hotHitsUkOverlapPW, mostNecessaryOverlapPW, topHitsGermanyOverlapPW, hotRhythmicOverlapPW,
                                      lswOverlapPW, baeOverlapPW, signedXoxoOverlapPW, channelXOverlapPW,
                                      workoutTwerkoutOverlapPW, hotHitsAusOverlapPW, bedroomJamsOverlapPW, mellowBarsOverlapPW,
                                      realestDownSouthOverlapPW, offTheStrengthOverlapPW, grimeShutdownOverlapPW, topHitsNLOverlapPW,
                                      hipHopCentralOverlapPW, singledOutOverlapPW, shishaLoungeOverlapPW, theNewnessOverlapPW, 
                                      lockedInOverlapPW, mindRightOverlapPW, caliFireOverlapPW, rapUKOverlapPW,
                                      hipHopMixtapeOverlapPW, whoWeBeOverlapPW, altHipHopOverlapPW, swagOverlapPW,
                                      cloutCultureOverlapPW, antiPopOverlapPW, spilledInkOverlapPW, rnbRightNowOverlapPW,
                                      stateOfMindOverlapPW, a1HipHopOverlapPW, hotHipHopOverlapPW, hipHopYogaOverlapPW,
                                      beatsRhymesOverlapPW, urbanFlavourOverlapPW, afroBashmentOverlapPW, newMusicNowOverlapPW,
                                      internetPeopleOverlapPW, hipHopMixOverlapPW, hotHitsNZOverlapPW)
powerWorkoutOverlapDF['Timegap'] =  (rapCavTimeGapPW, beastModeTimeGapPW, getTurntTimeGapPW, powerWorkoutTimeGapPW,
                                      hotHitsUkTimeGapPW, mostNecessaryTimeGapPW, topHitsGermanyTimeGapPW, hotRhythmicTimeGapPW,
                                      lswTimeGapPW, baeTimeGapPW, signedXoxoTimeGapPW, channelXTimeGapPW,
                                      workoutTwerkoutTimeGapPW, hotHitsAusTimeGapPW, bedroomJamsTimeGapPW, mellowBarsTimeGapPW,
                                      realestDownSouthTimeGapPW, offTheStrengthTimeGapPW, grimeShutdownTimeGapPW, topHitsNlTimeGapPW,
                                      hipHopCentralTimeGapPW, singledOutTimeGapPW, shishaLoungeTimeGapPW, theNewnessTimeGapPW, 
                                      lockedInTimeGapPW, mindRightTimeGapPW, caliFireTimeGapPW, rapUkTimeGapPW,
                                      hipHopMixtapeTimeGapPW, whoWeBeTimeGapPW, altHipHopTimeGapPW, swagTimeGapPW,
                                      cloutCultureTimeGapPW, antiPopTimeGapPW, spilledInkTimeGapPW, rnbRightNowTimeGapPW,
                                      stateOfMindTimeGapPW, a1HipHopTimeGapPW, hotHipHopTimeGapPW, hipHopYogaTimeGapPW,
                                      beatsRhymesTimeGapPW, urbanFlavourTimeGapPW, afroBashmentTimeGapPW, newMusicNowTimeGapPW,
                                      internetPeopleTimeGapPW, hipHopMixTimeGapPW, hotHitsNZTimeGapPW)

powerWorkoutOverlapDF.reset_index(drop=True)
format_dict_new_PW = {'Playlist Followers': '{:,}', 'Overlap':'{:.2%}', 'Timegap':'{:,.0f}'}
powerWorkoutOverlapDF = powerWorkoutOverlapDF[powerWorkoutOverlapDF.Overlap != 0]
# powerWorkoutOverlapDF = powerWorkoutOverlapDF[powerWorkoutOverlapDF.Overlap != 1]
powerWorkoutOverlapDF.columns = powerWorkoutOverlapDF.columns.str.replace('_', ' ')
powerWorkoutOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new_PW).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('Power Workout Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_af1a4eea_6556_11ea_b195_3af9d3abd3acrow0_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_af1a4eea_6556_11ea_b195_3af9d3abd3acrow1_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_af1a4eea_6556_11ea_b195_3af9d3abd3acrow2_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_af1a4eea_6556_11ea_b195_3af9d3abd3acrow3_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_af1a4eea_6556_11ea_b195_3af9d3abd3acrow4_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
# ...

# %% [markdown]
# # Most Necessary Path

# %%
mostNecessaryOverlap = rap.loc[rap['Most_Necessary']==1]
mostNecessaryOverlap = mostNecessaryOverlap[mostNecessaryOverlap['Days_On_Most_Necessary'].isin([0.0])]

hotHitsNZOverlap = mostNecessaryOverlap['Hot_Hits_New_Zealand'].value_counts(normalize=True)
hotHitsNZOverlap = 1 - hotHitsNZOverlap[0]

hotHitsNZTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hot_Hits_New_Zealand'].notnull()]
hotHitsNZTimeGap = hotHitsNZTimeGap['Days_On_Hot_Hits_New_Zealand'].mean()

hipHopMixOverlap = mostNecessaryOverlap['Hip_Hop_Mix'].value_counts(normalize=True)
hipHopMixOverlap = 1 - hipHopMixOverlap[0]

hipHopMixTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hip_Hop_Mix'].notnull()]
hipHopMixTimeGap = hipHopMixTimeGap['Days_On_Hip_Hop_Mix'].mean()

internetPeopleOverlap = mostNecessaryOverlap['Internet_People'].value_counts(normalize=True)
internetPeopleOverlap = 1 - internetPeopleOverlap[0]

internetPeopleTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Internet_People'].notnull()]
internetPeopleTimeGap = internetPeopleTimeGap['Days_On_Internet_People'].mean()

newMusicNowOverlap = mostNecessaryOverlap['New_Music_Now'].value_counts(normalize=True)
newMusicNowOverlap = 1 - newMusicNowOverlap[0]

newMusicNowTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_New_Music_Now'].notnull()]
newMusicNowTimeGap = newMusicNowTimeGap['Days_On_New_Music_Now'].mean()

afroBashmentOverlap = mostNecessaryOverlap['Afro_Bashment'].value_counts(normalize=True)
afroBashmentOverlap = 1 - afroBashmentOverlap[0]

afroBashmentTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Afro_Bashment'].notnull()]
afroBashmentTimeGap = afroBashmentTimeGap['Days_On_Afro_Bashment'].mean()

urbanFlavourOverlap = mostNecessaryOverlap['Urban_Flavour'].value_counts(normalize=True)
urbanFlavourOverlap = 1 - urbanFlavourOverlap[0]

urbanFlavourTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Urban_Flavour'].notnull()]
urbanFlavourTimeGap = urbanFlavourTimeGap['Days_On_Urban_Flavour'].mean()

beatsRhymesOverlap = mostNecessaryOverlap['Beats_&_Rhymes'].value_counts(normalize=True)
beatsRhymesOverlap = 1 - beatsRhymesOverlap[0]

beatsRhymesTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Beats_&_Rhymes'].notnull()]
beatsRhymesTimeGap = beatsRhymesTimeGap['Days_On_Beats_&_Rhymes'].mean()

hipHopYogaOverlap = mostNecessaryOverlap['Hip-Hop_Yoga'].value_counts(normalize=True)
hipHopYogaOverlap = 1 - hipHopYogaOverlap[0]

hipHopYogaTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hip-Hop_Yoga'].notnull()]
hipHopYogaTimeGap = hipHopYogaTimeGap['Days_On_Hip-Hop_Yoga'].mean()

hotHipHopOverlap = mostNecessaryOverlap['Hot_Hip_Hop'].value_counts(normalize=True)
hotHipHopOverlap = 1 - hotHipHopOverlap[0]

hotHipHopTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hot_Hip_Hop'].notnull()]
hotHipHopTimeGap = hotHipHopTimeGap['Days_On_Hot_Hip_Hop'].mean()

a1HipHopOverlap = mostNecessaryOverlap['A1_Hip-Hop'].value_counts(normalize=True)
a1HipHopOverlap = 1 - a1HipHopOverlap[0]

a1HipHopTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_A1_Hip-Hop'].notnull()]
a1HipHopTimeGap = a1HipHopTimeGap['Days_On_A1_Hip-Hop'].mean()

stateOfMindOverlap = mostNecessaryOverlap['State_of_Mind'].value_counts(normalize=True)
stateOfMindOverlap = 1 - stateOfMindOverlap[0]

stateOfMindTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_State_of_Mind'].notnull()]
stateOfMindTimeGap = stateOfMindTimeGap['Days_On_State_of_Mind'].mean()

rnbRightNowOverlap = mostNecessaryOverlap['R&B_Right_Now'].value_counts(normalize=True)
rnbRightNowOverlap = 1 - rnbRightNowOverlap[0]

rnbRightNowTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_R&B_Right_Now'].notnull()]
rnbRightNowTimeGap = rnbRightNowTimeGap['Days_On_R&B_Right_Now'].mean()

spilledInkOverlap = mostNecessaryOverlap['Spilled_Ink'].value_counts(normalize=True)
spilledInkOverlap = 1 - spilledInkOverlap[0]

spilledInkTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Spilled_Ink'].notnull()]
spilledInkTimeGap = spilledInkTimeGap['Days_On_Spilled_Ink'].mean()

antiPopOverlap = mostNecessaryOverlap['Anti_Pop'].value_counts(normalize=True)
antiPopOverlap = 1 - antiPopOverlap[0]

antiPopTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Anti_Pop'].notnull()]
antiPopTimeGap = antiPopTimeGap['Days_On_Anti_Pop'].mean()

cloutCultureOverlap = mostNecessaryOverlap['Clout_Culture'].value_counts(normalize=True)
cloutCultureOverlap = 1 - cloutCultureOverlap[0]

cloutCultureTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Clout_Culture'].notnull()]
cloutCultureTimeGap = cloutCultureTimeGap['Days_On_Clout_Culture'].mean()

swagOverlap = mostNecessaryOverlap['Swag!'].value_counts(normalize=True)
swagOverlap = 1 - swagOverlap[0]

swagTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Swag!'].notnull()]
swagTimeGap = swagTimeGap['Days_On_Swag!'].mean()

altHipHopOverlap = mostNecessaryOverlap['Alternative_Hip_Hop'].value_counts(normalize=True)
altHipHopOverlap = 1 - altHipHopOverlap[0]

altHipHopTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Alternative_Hip_Hop'].notnull()]
altHipHopTimeGap = altHipHopTimeGap['Days_On_Alternative_Hip_Hop'].mean()

whoWeBeOverlap = mostNecessaryOverlap['Who_We_Be'].value_counts(normalize=True)
whoWeBeOverlap = 1 - whoWeBeOverlap[0]

whoWeBeTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Who_We_Be'].notnull()]
whoWeBeTimeGap = whoWeBeTimeGap['Days_On_Who_We_Be'].mean()

hipHopMixtapeOverlap = mostNecessaryOverlap['Hip-Hop_Mixtape'].value_counts(normalize=True)
hipHopMixtapeOverlap = 1 - hipHopMixtapeOverlap[0]

hipHopMixtapeTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hip-Hop_Mixtape'].notnull()]
hipHopMixtapeTimeGap = hipHopMixtapeTimeGap['Days_On_Hip-Hop_Mixtape'].mean()

rapUKOverlap = mostNecessaryOverlap['Rap_UK'].value_counts(normalize=True)
rapUKOverlap = 1 - rapUKOverlap[0]

rapUkTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Rap_UK'].notnull()]
rapUkTimeGap = rapUkTimeGap['Days_On_Rap_UK'].mean()

caliFireOverlap = mostNecessaryOverlap['Cali_Fire'].value_counts(normalize=True)
caliFireOverlap = 1 - caliFireOverlap[0]

caliFireTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Cali_Fire'].notnull()]
caliFireTimeGap = caliFireTimeGap['Days_On_Cali_Fire'].mean()

mindRightOverlap = mostNecessaryOverlap['Mind_Right'].value_counts(normalize=True)
mindRightOverlap = 1 - mindRightOverlap[0]

mindRightTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Mind_Right'].notnull()]
mindRightTimeGap = mindRightTimeGap['Days_On_Mind_Right'].mean()

lockedInOverlap = mostNecessaryOverlap['Locked_In'].value_counts(normalize=True)
lockedInOverlap = 1 - lockedInOverlap[0]

lockedInTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Locked_In'].notnull()]
lockedInTimeGap = lockedInTimeGap['Days_On_Locked_In'].mean()

theNewnessOverlap = mostNecessaryOverlap['The_Newness'].value_counts(normalize=True)
theNewnessOverlap = 1 - theNewnessOverlap[0]

theNewnessTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_The_Newness'].notnull()]
theNewnessTimeGap = theNewnessTimeGap['Days_On_The_Newness'].mean()

shishaLoungeOverlap = mostNecessaryOverlap['Shisha_Lounge'].value_counts(normalize=True)
shishaLoungeOverlap = 1 - shishaLoungeOverlap[0]

shishaLoungeTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Shisha_Lounge'].notnull()]
shishaLoungeTimeGap = shishaLoungeTimeGap['Days_On_Shisha_Lounge'].mean()

singledOutOverlap = mostNecessaryOverlap['Singled_Out'].value_counts(normalize=True)
singledOutOverlap = 1 - singledOutOverlap[0]

singledOutTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Singled_Out'].notnull()]
singledOutTimeGap = singledOutTimeGap['Days_On_Singled_Out'].mean()

hipHopCentralOverlap = mostNecessaryOverlap['Hip-Hop_Central'].value_counts(normalize=True)
hipHopCentralOverlap = 1 - hipHopCentralOverlap[0]

hipHopCentralTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hip-Hop_Central'].notnull()]
hipHopCentralTimeGap = hipHopCentralTimeGap['Days_On_Hip-Hop_Central'].mean()

topHitsNLOverlap = mostNecessaryOverlap['Top_Hits_NL'].value_counts(normalize=True)
topHitsNLOverlap = 1 - topHitsNLOverlap[0]

topHitsNlTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Top_Hits_NL'].notnull()]
topHitsNlTimeGap = topHitsNlTimeGap['Days_On_Top_Hits_NL'].mean()

grimeShutdownOverlap = mostNecessaryOverlap['Grime_Shutdown'].value_counts(normalize=True)
grimeShutdownOverlap = 1 - grimeShutdownOverlap[0]

grimeShutdownTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Grime_Shutdown'].notnull()]
grimeShutdownTimeGap = grimeShutdownTimeGap['Days_On_Grime_Shutdown'].mean()

offTheStrengthOverlap = mostNecessaryOverlap['Off_The_Strength'].value_counts(normalize=True)
offTheStrengthOverlap = 1 - offTheStrengthOverlap[0]

offTheStrengthTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Off_The_Strength'].notnull()]
offTheStrengthTimeGap = offTheStrengthTimeGap['Days_On_Off_The_Strength'].mean()

realestDownSouthOverlap = mostNecessaryOverlap['The_Realest_Down_South'].value_counts(normalize=True)
realestDownSouthOverlap = 1 - realestDownSouthOverlap[0]

realestDownSouthTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_The_Realest_Down_South'].notnull()]
realestDownSouthTimeGap = realestDownSouthTimeGap['Days_On_The_Realest_Down_South'].mean()

mellowBarsOverlap = mostNecessaryOverlap['Mellow_Bars'].value_counts(normalize=True)
mellowBarsOverlap = 1 - mellowBarsOverlap[0]

mellowBarsTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Mellow_Bars'].notnull()]
mellowBarsTimeGap = mellowBarsTimeGap['Days_On_Mellow_Bars'].mean()

bedroomJamsOverlap = mostNecessaryOverlap['Bedroom_Jams'].value_counts(normalize=True)
bedroomJamsOverlap = 1 - bedroomJamsOverlap[0]

bedroomJamsTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Bedroom_Jams'].notnull()]
bedroomJamsTimeGap = bedroomJamsTimeGap['Days_On_Bedroom_Jams'].mean()

hotHitsAusOverlap = mostNecessaryOverlap['Hot_Hits_Australia'].value_counts(normalize=True)
hotHitsAusOverlap = 1 - hotHitsAusOverlap[0]

hotHitsAusTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hot_Hits_Australia'].notnull()]
hotHitsAusTimeGap = hotHitsAusTimeGap['Days_On_Hot_Hits_Australia'].mean()

workoutTwerkoutOverlap = mostNecessaryOverlap['Workout_Twerkout'].value_counts(normalize=True)
workoutTwerkoutOverlap = 1 - workoutTwerkoutOverlap[0]

workoutTwerkoutTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Workout_Twerkout'].notnull()]
workoutTwerkoutTimeGap = workoutTwerkoutTimeGap['Days_On_Workout_Twerkout'].mean()

channelXOverlap = mostNecessaryOverlap['Channel_X'].value_counts(normalize=True)
channelXOverlap = 1 - channelXOverlap[0]

channelXTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Channel_X'].notnull()]
channelXTimeGap = channelXTimeGap['Days_On_Channel_X'].mean()

signedXoxoOverlap = mostNecessaryOverlap['Signed_XOXO'].value_counts(normalize=True)
signedXoxoOverlap = 1 - signedXoxoOverlap[0]

signedXoxoTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Signed_XOXO'].notnull()]
signedXoxoTimeGap = signedXoxoTimeGap['Days_On_Signed_XOXO'].mean()

baeOverlap = mostNecessaryOverlap['BAE'].value_counts(normalize=True)
baeOverlap = 1 - baeOverlap[0]

baeTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_BAE'].notnull()]
baeTimeGap = baeTimeGap['Days_On_BAE'].mean()

lswOverlap = mostNecessaryOverlap['Love,_Sex,_&_Water'].value_counts(normalize=True)
lswOverlap = 1 - lswOverlap[0]

lswTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Love,_Sex,_&_Water'].notnull()]
lswTimeGap = lswTimeGap['Days_On_Love,_Sex,_&_Water'].mean()

hotRhythmicOverlap = mostNecessaryOverlap['Hot_Rhythmic'].value_counts(normalize=True)
hotRhythmicOverlap = 1 - hotRhythmicOverlap[0]

hotRhythmicTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hot_Rhythmic'].notnull()]
hotRhythmicTimeGap = hotRhythmicTimeGap['Days_On_Hot_Rhythmic'].mean()

topHitsGermanyOverlap = mostNecessaryOverlap['Top_Hits_Deutschland'].value_counts(normalize=True)
topHitsGermanyOverlap = 1 - topHitsGermanyOverlap[0]

topHitsGermanyTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Top_Hits_Deutschland'].notnull()]
topHitsGermanyTimeGap = topHitsGermanyTimeGap['Days_On_Top_Hits_Deutschland'].mean()

hotHitsUkOverlap = mostNecessaryOverlap['Hot_Hits_UK'].value_counts(normalize=True)
hotHitsUkOverlap = 1 - hotHitsUkOverlap[0]

hotHitsUkTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Hot_Hits_UK'].notnull()]
hotHitsUkTimeGap = hotHitsUkTimeGap['Days_On_Hot_Hits_UK'].mean()

beastModeOverlap = mostNecessaryOverlap['Beast_Mode'].value_counts(normalize=True)
beastModeOverlap = 1 - beastModeOverlap[0]

beastModeTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Beast_Mode'].notnull()]
beastModeTimeGap = beastModeTimeGap['Days_On_Beast_Mode'].mean()

getTurntOverlap = mostNecessaryOverlap['Get_Turnt'].value_counts(normalize=True)
getTurntOverlap = 1 - getTurntOverlap[0]

getTurntTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Get_Turnt'].notnull()]
getTurntTimeGap = getTurntTimeGap['Days_On_Get_Turnt'].mean()

powerWorkoutOverlap = mostNecessaryOverlap['Power_Workout'].value_counts(normalize=True)
powerWorkoutOverlap = 1 - powerWorkoutOverlap[0]

powerWorkoutTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_Power_Workout'].notnull()]
powerWorkoutTimeGap = powerWorkoutTimeGap['Days_On_Power_Workout'].mean()

rapCavOverlap = mostNecessaryOverlap['RapCaviar'].value_counts(normalize=True)
rapCavOverlap = 1 - rapCavOverlap[0]

rapCavTimeGap = mostNecessaryOverlap.loc[mostNecessaryOverlap['Days_On_RapCaviar'].notnull()]
rapCavTimeGap = rapCavTimeGap['Days_On_RapCaviar'].mean()

# %%
mostNecessaryTimeGap = 0
mostNecessaryTimeGap
# Out:
# 0

# %% [markdown]
# # Most Necessary Overlap Table

# %%
mostNecessaryOverlapDF = rapStatsAgg.iloc[:,0:2].sort_values('Playlist_Followers', ascending=False)
mostNecessaryOverlapDF['Overlap'] =  (rapCavOverlap, beastModeOverlap, getTurntOverlap, powerWorkoutOverlap,
                                      hotHitsUkOverlap, 1, topHitsGermanyOverlap, hotRhythmicOverlap,
                                      lswOverlap, baeOverlap, signedXoxoOverlap, channelXOverlap,
                                      workoutTwerkoutOverlap, hotHitsAusOverlap, bedroomJamsOverlap, mellowBarsOverlap,
                                      realestDownSouthOverlap, offTheStrengthOverlap, grimeShutdownOverlap, topHitsNLOverlap,
                                      hipHopCentralOverlap, singledOutOverlap, shishaLoungeOverlap, theNewnessOverlap, 
                                      lockedInOverlap, mindRightOverlap, caliFireOverlap, rapUKOverlap,
                                      hipHopMixtapeOverlap, whoWeBeOverlap, altHipHopOverlap, swagOverlap,
                                      cloutCultureOverlap, antiPopOverlap, spilledInkOverlap, rnbRightNowOverlap,
                                      stateOfMindOverlap, a1HipHopOverlap, hotHipHopOverlap, hipHopYogaOverlap,
                                      beatsRhymesOverlap, urbanFlavourOverlap, afroBashmentOverlap, newMusicNowOverlap,
                                      internetPeopleOverlap, hipHopMixOverlap, hotHitsNZOverlap)
mostNecessaryOverlapDF['Timegap'] =  (rapCavTimeGap, beastModeTimeGap, getTurntTimeGap, powerWorkoutTimeGap,
                                      hotHitsUkTimeGap, mostNecessaryTimeGap, topHitsGermanyTimeGap, hotRhythmicTimeGap,
                                      lswTimeGap, baeTimeGap, signedXoxoTimeGap, channelXTimeGap,
                                      workoutTwerkoutTimeGap, hotHitsAusTimeGap, bedroomJamsTimeGap, mellowBarsTimeGap,
                                      realestDownSouthTimeGap, offTheStrengthTimeGap, grimeShutdownTimeGap, topHitsNlTimeGap,
                                      hipHopCentralTimeGap, singledOutTimeGap, shishaLoungeTimeGap, theNewnessTimeGap, 
                                      lockedInTimeGap, mindRightTimeGap, caliFireTimeGap, rapUkTimeGap,
                                      hipHopMixtapeTimeGap, whoWeBeTimeGap, altHipHopTimeGap, swagTimeGap,
                                      cloutCultureTimeGap, antiPopTimeGap, spilledInkTimeGap, rnbRightNowTimeGap,
                                      stateOfMindTimeGap, a1HipHopTimeGap, hotHipHopTimeGap, hipHopYogaTimeGap,
                                      beatsRhymesTimeGap, urbanFlavourTimeGap, afroBashmentTimeGap, newMusicNowTimeGap,
                                      internetPeopleTimeGap, hipHopMixTimeGap, hotHitsNZTimeGap)

mostNecessaryOverlapDF.reset_index(drop=True)
format_dict_new = {'Playlist Followers': '{:,}', 'Overlap':'{:.2%}', 'Timegap':'{:,.0f}'}
mostNecessaryOverlapDF = mostNecessaryOverlapDF[mostNecessaryOverlapDF.Overlap != 0]
mostNecessaryOverlapDF = mostNecessaryOverlapDF[mostNecessaryOverlapDF.Overlap != 1]
mostNecessaryOverlapDF.columns = mostNecessaryOverlapDF.columns.str.replace('_', ' ')
mostNecessaryOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('Most Necessary Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_becab762_6556_11ea_b195_3af9d3abd3acrow0_col2 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_becab762_6556_11ea_b195_3af9d3abd3acrow1_col2 {
#             background-color:  #ffae00;
#             color:  #000000;
#         }    #T_becab762_6556_11ea_b195_3af9d3abd3acrow2_col2 {
#             background-color:  #ffe81b;
#             color:  #000000;
#         }    #T_becab762_6556_11ea_b195_3af9d3abd3acrow3_col2 {
#             background-color:  #ffe81b;
#             color:  #000000;
#         }    #T_becab762_6556_11ea_b195_3af9d3abd3acrow4_col2 {
#             background-color:  #f1f44b;
#             color:  #000000;
#         }    #T_becab762_6556_11ea_b195_3af9d3abd3acrow5_col2 {
#             background-color:  #f1f44b;
#             color:  #000000;
#         }    #T_becab762_6556_11ea_b195_3af9d3abd3acrow6_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
# ...

# %%
plt.figure(figsize=(20,20))
sns.barplot(x='Playlist Followers', y='Overlap', data=mostNecessaryOverlapDF, order=mostNecessaryOverlapDF['Playlist Followers']).set_title('Most Necessary Playlist Overlap')
# Out:
# Text(0.5, 1.0, 'Most Necessary Playlist Overlap')

# %% [markdown]
# # Top 5 Rap Overlaps

# %%
rapCaviarOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new_RC).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('RapCaviar Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_ddbe8cee_631b_11ea_96ce_3af9d3abd3acrow0_col2 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_ddbe8cee_631b_11ea_96ce_3af9d3abd3acrow1_col2 {
#             background-color:  #ffaa00;
#             color:  #000000;
#         }    #T_ddbe8cee_631b_11ea_96ce_3af9d3abd3acrow2_col2 {
#             background-color:  #ffbd00;
#             color:  #000000;
#         }    #T_ddbe8cee_631b_11ea_96ce_3af9d3abd3acrow3_col2 {
#             background-color:  #f6f03b;
#             color:  #000000;
#         }    #T_ddbe8cee_631b_11ea_96ce_3af9d3abd3acrow4_col2 {
#             background-color:  #f6f03b;
#             color:  #000000;
#         }    #T_ddbe8cee_631b_11ea_96ce_3af9d3abd3acrow5_col2 {
#             background-color:  #f6f03b;
#             color:  #000000;
#         }    #T_ddbe8cee_631b_11ea_96ce_3af9d3abd3acrow6_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
# ...

# %%
beastModeOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new_BM).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('Beast Mode Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_e7263dae_631b_11ea_96ce_3af9d3abd3acrow0_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_e7263dae_631b_11ea_96ce_3af9d3abd3acrow1_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_e7263dae_631b_11ea_96ce_3af9d3abd3acrow2_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_e7263dae_631b_11ea_96ce_3af9d3abd3acrow3_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_e7263dae_631b_11ea_96ce_3af9d3abd3acrow4_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_e7263dae_631b_11ea_96ce_3af9d3abd3acrow5_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_e7263dae_631b_11ea_96ce_3af9d3abd3acrow6_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
# ...

# %%
getTurntOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new_GT).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('Get Turnt Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_ef2f65fc_631b_11ea_96ce_3af9d3abd3acrow0_col2 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_ef2f65fc_631b_11ea_96ce_3af9d3abd3acrow1_col2 {
#             background-color:  #ffb600;
#             color:  #000000;
#         }    #T_ef2f65fc_631b_11ea_96ce_3af9d3abd3acrow2_col2 {
#             background-color:  #ffb600;
#             color:  #000000;
#         }    #T_ef2f65fc_631b_11ea_96ce_3af9d3abd3acrow3_col2 {
#             background-color:  #ffc706;
#             color:  #000000;
#         }    #T_ef2f65fc_631b_11ea_96ce_3af9d3abd3acrow4_col2 {
#             background-color:  #f0f550;
#             color:  #000000;
#         }    #T_ef2f65fc_631b_11ea_96ce_3af9d3abd3acrow5_col2 {
#             background-color:  #f0f550;
#             color:  #000000;
#         }    #T_ef2f65fc_631b_11ea_96ce_3af9d3abd3acrow6_col2 {
#             background-color:  #f0f550;
#             color:  #000000;
# ...

# %%
powerWorkoutOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new_PW).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('Power Workout Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_f6d28654_631b_11ea_96ce_3af9d3abd3acrow0_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_f6d28654_631b_11ea_96ce_3af9d3abd3acrow1_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_f6d28654_631b_11ea_96ce_3af9d3abd3acrow2_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_f6d28654_631b_11ea_96ce_3af9d3abd3acrow3_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_f6d28654_631b_11ea_96ce_3af9d3abd3acrow4_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
# ...

# %%
mostNecessaryOverlapDF.sort_values('Overlap', ascending=False).style.format(format_dict_new).hide_index().background_gradient(subset='Overlap', cmap='Wistia').set_caption('Most Necessary Target Playlist: Overlap')
# Out:
# <style  type="text/css" >
#     #T_fc4de83a_631b_11ea_96ce_3af9d3abd3acrow0_col2 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_fc4de83a_631b_11ea_96ce_3af9d3abd3acrow1_col2 {
#             background-color:  #ffae00;
#             color:  #000000;
#         }    #T_fc4de83a_631b_11ea_96ce_3af9d3abd3acrow2_col2 {
#             background-color:  #ffe81b;
#             color:  #000000;
#         }    #T_fc4de83a_631b_11ea_96ce_3af9d3abd3acrow3_col2 {
#             background-color:  #ffe81b;
#             color:  #000000;
#         }    #T_fc4de83a_631b_11ea_96ce_3af9d3abd3acrow4_col2 {
#             background-color:  #f1f44b;
#             color:  #000000;
#         }    #T_fc4de83a_631b_11ea_96ce_3af9d3abd3acrow5_col2 {
#             background-color:  #f1f44b;
#             color:  #000000;
#         }    #T_fc4de83a_631b_11ea_96ce_3af9d3abd3acrow6_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
# ...
